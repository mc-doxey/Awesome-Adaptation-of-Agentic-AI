# %% [markdown]
# <a href="https://colab.research.google.com/github/mc-doxey/Awesome-Adaptation-of-Agentic-AI/blob/main/safety_nest_01_patient_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 00 - Intro

# %%
## 00. SETUP PERSISTENT STORAGE
from google.colab import drive
import os

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
## 01. Define Persistent Paths
## We will save everything here so it survives a runtime restart
BASE_DRIVE_PATH = "/content/drive/MyDrive/SafetyNest_Data"
CLEAN_DATA_DIR = os.path.join(BASE_DRIVE_PATH, "fhir_clean")
DIRTY_DATA_DIR = os.path.join(BASE_DRIVE_PATH, "fhir_dirty")

# 3. Create Directories if they don't exist
os.makedirs(CLEAN_DATA_DIR, exist_ok=True)
os.makedirs(DIRTY_DATA_DIR, exist_ok=True)

print(f"✅ Storage Configured.")
print(f"📂 Clean Data: {CLEAN_DATA_DIR}")
print(f"📂 Dirty Data: {DIRTY_DATA_DIR}")
# Out:
# ✅ Storage Configured.
# 📂 Clean Data: /content/drive/MyDrive/SafetyNest_Data/fhir_clean
# 📂 Dirty Data: /content/drive/MyDrive/SafetyNest_Data/fhir_dirty

# %%
print(f"Checking contents of local Synthea output directory: {LOCAL_SYNTHEA_OUTPUT_DIR}")
if os.path.exists(LOCAL_SYNTHEA_OUTPUT_DIR) and os.listdir(LOCAL_SYNTHEA_OUTPUT_DIR):
    print(f"Found files in local directory. First 5 files: {os.listdir(LOCAL_SYNTHEA_OUTPUT_DIR)[:5]}...")
    # If files are found locally, copy them to the FHIR_CLEAN_DIR on Drive
    print(f"Copying files from {LOCAL_SYNTHEA_OUTPUT_DIR} to {FHIR_CLEAN_DIR} for persistence...")
    # !cp -r "{LOCAL_SYNTHEA_OUTPUT_DIR}"/* "{FHIR_CLEAN_DIR}"
    print("✅ Files copied to Google Drive.")
    # Optionally, remove local files to free up space (be careful with this)
    # !rm -r "{LOCAL_SYNTHEA_OUTPUT_DIR}"
else:
    print(f"No files found in local Synthea output directory: {LOCAL_SYNTHEA_OUTPUT_DIR}")
    print("This indicates Synthea might not have generated files, or they are in an unexpected location.")
    print(f"Listing contents of {FHIR_CLEAN_DIR} to confirm it's still empty: {os.listdir(FHIR_CLEAN_DIR)}")
# Out:
# Checking contents of local Synthea output directory: /content/output/fhir
# Found files in local directory. First 5 files: ['Laverne101_Torphy630_7b7c1667-e930-2f94-1e0e-1e74e2f7b41f.json', 'Colin861_Mayert710_608c8dce-a577-4b05-f962-6fef90986a3a.json', 'Eldridge510_Hand679_52c4ccb1-a216-cced-ae1d-a5120c628011.json', 'Mark765_Schuster709_46eab0c9-da7b-1910-9245-4f2f8da7965c.json', 'Irvin970_Parker433_d7ecdd8c-150c-369e-a929-1b7939a9b3ab.json']...
# Copying files from /content/output/fhir to /content/drive/MyDrive/Synthea_Data/fhir_output/clean for persistence...
# ✅ Files copied to Google Drive.

# %% [markdown]
# # 01 - Synthetic Data

# %% [markdown]
# ## 01a - Get Synthea Data

# %%
import glob
import shutil

# Check if we already have data
existing_files = glob.glob(f"{CLEAN_DATA_DIR}/*.json")

if len(existing_files) >= 1000:
    print(f"✅ Found {len(existing_files)} existing patient records in Drive.")
    print("⏭️ Skipping Synthea Generation.")

else:
    print("⚠️ Data not found (or incomplete). Starting Fresh Generation...")

    # 1. Install Java & Download Synthea (Local VM)
    # !apt-get install openjdk-8-jdk-headless -qq > /dev/null
    # !wget -q https://github.com/synthetichealth/synthea/releases/download/v3.0.0/synthea-with-dependencies.jar -O synthea.jar

    # 2. Run Synthea (Generate locally first for speed)
    print("🏥 Generating 1000 Patients locally...")
    # !java -jar synthea.jar -p 1000 -a 0-17 --exporter.baseDirectory "./temp_output"

    # 3. Move to Drive (Persistence)
    print(f"💾 Copying files to Google Drive: {CLEAN_DATA_DIR}...")

    # Synthea creates subfolders, we want the files in 'fhir'
    local_fhir_path = "./temp_output/fhir"
    for file_name in os.listdir(local_fhir_path):
        full_file_name = os.path.join(local_fhir_path, file_name)
        if os.path.isfile(full_file_name):
            shutil.copy(full_file_name, CLEAN_DATA_DIR)

    print("✅ Data successfully saved to Drive.")
# Out:
# ⚠️ Data not found (or incomplete). Starting Fresh Generation...
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/universe/o/openjdk-8/openjdk-8-jre-headless_8u472-ga-1%7e22.04_amd64.deb  404  Not Found [IP: 91.189.91.82 80]
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/universe/o/openjdk-8/openjdk-8-jdk-headless_8u472-ga-1%7e22.04_amd64.deb  404  Not Found [IP: 91.189.91.82 80]
# E: Unable to fetch some archives, maybe run apt-get update or try with --fix-missing?
# 🏥 Generating 1000 Patients locally...
# Scanned 67 modules and 75 submodules.
# Loading submodule modules/breast_cancer/tnm_diagnosis.json
# Loading submodule modules/encounter/anxiety_screening.json
# Loading submodule modules/covid19/nonsurvivor_lab_values.json
# Loading submodule modules/covid19/outcomes.json
# Loading submodule modules/covid19/survivor_lab_values.json
# Loading submodule modules/dermatitis/moderate_cd_obs.json
# Loading submodule modules/covid19/diagnose_blood_clot.json
# Loading submodule modules/dermatitis/severe_cd_obs.json
# Loading submodule modules/contraceptives/female_sterilization.json
# Loading submodule modules/allergies/outgrow_env_allergies.json
# Loading submodule modules/covid19/medications.json
# Loading submodule modules/encounter/vitals.json
# Loading submodule modules/heart/chf_meds.json
# Loading submodule modules/lung_cancer/lung_cancer_probabilities.json
# Loading submodule modules/contraceptives/patch_contraceptive.json
# Loading submodule modules/heart/chf_lvad.json
# Loading submodule modules/allergies/allergy_panel.json
# Loading submodule modules/covid19/supplies_hospitalization.json
# Loading submodule modules/breast_cancer/surgery_therapy_breast.json
# Loading submodule modules/allergies/severe_allergic_reaction.json
# Loading submodule modules/covid19/supplies_intubation.json
# Loading submodule modules/covid19/infection.json
# Loading submodule modules/dermatitis/early_severe_eczema_obs.json
# Loading submodule modules/total_joint_replacement/functional_status_assessments.json
# Loading submodule modules/encounter/depression_screening.json
# Loading submodule modules/weight_loss/mend_week.json
# Loading submodule modules/heart/chf_lab_work.json
# Loading submodule modules/contraceptives/ring_contraceptive.json
# Loading submodule modules/covid19/end_symptoms.json
# Loading submodule modules/covid19/diagnose_bacterial_infection.json
# Loading submodule modules/encounter/substance_use_screening.json
# Loading submodule modules/anemia/anemia_sub.json
# Loading submodule modules/heart/chf_transplant.json
# Loading submodule modules/medications/otc_pain_reliever.json
# Loading submodule modules/breast_cancer/hormone_diagnosis.json
# Loading submodule modules/allergies/drug_allergy_incidence.json
# Loading submodule modules/covid19/supplies_icu.json
# Loading submodule modules/medications/strong_opioid_pain_reliever.json
# Loading submodule modules/medications/ear_infection_antibiotic.json
# Loading submodule modules/allergies/immunotherapy.json
# Loading submodule modules/encounter/sdoh_hrsn.json
# Loading submodule modules/dermatitis/mid_moderate_eczema_obs.json
# Loading submodule modules/contraceptives/clear_contraceptive.json
# Loading submodule modules/heart/chf_meds_hfmef.json
# Loading submodule modules/covid19/end_outcomes.json
# Loading submodule modules/heart/chf_nyha_panel.json
# Loading submodule modules/surgery/general_anesthesia.json
# Loading submodule modules/veterans/veteran_suicide_probabilities.json
# Loading submodule modules/contraceptives/oral_contraceptive.json
# Loading submodule modules/medications/moderate_opioid_pain_reliever.json
# Loading submodule modules/covid19/measurements_vitals.json
# Loading submodule modules/medications/otc_antihistamine.json
# Loading submodule modules/covid19/determine_risk.json
# Loading Lookup Table: covid-19-severity-outcomes.csv
# Loading Lookup Table: covid-19-survival-outcomes.csv
# Loading submodule modules/covid19/admission.json
# Loading submodule modules/allergies/environmental_allergy_incidence.json
# Loading submodule modules/covid19/measurements_frequent.json
# Loading submodule modules/allergies/food_allergy_incidence.json
# Loading submodule modules/dermatitis/mid_severe_eczema_obs.json
# Loading submodule modules/dermatitis/early_moderate_eczema_obs.json
# Loading submodule modules/covid19/symptoms.json
# Loading submodule modules/encounter/hark_screening.json
# Loading submodule modules/contraceptives/intrauterine_device.json
# Loading submodule modules/contraceptives/male_sterilization.json
# Loading submodule modules/heart/chf_meds_hfref_nyha3.json
# Loading submodule modules/contraceptives/implant_contraceptive.json
# Loading submodule modules/heart/chf_meds_hfref_nyha4.json
# Loading submodule modules/breast_cancer/hormonetherapy_breast.json
# Loading submodule modules/heart/chf_meds_hfref_nyha2.json
# Loading submodule modules/encounter/fall_risk_screening.json
# Loading submodule modules/contraceptives/injectable_contraceptive.json
# Loading submodule modules/covid19/measurements_daily.json
# Loading submodule modules/covid19/treat_blood_clot.json
# Loading submodule modules/medications/hypertension_medication.json
# Loading submodule modules/allergies/outgrow_food_allergies.json
# Loading submodule modules/breast_cancer/chemotherapy_breast.json
# Loading module modules/opioid_addiction.json
# Loading module modules/cerebral_palsy.json
# Loading module modules/dialysis.json
# Loading module modules/allergic_rhinitis.json
# Loading module modules/pregnancy.json
# Loading module modules/atopy.json
# Loading module modules/self_harm.json
# Loading module modules/asthma.json
# Loading module modules/covid19.json
# Loading Lookup Table: covid19_prob.csv
# Loading module modules/ear_infections.json
# Loading module modules/sinusitis.json
# Loading module modules/dementia.json
# Loading module modules/veteran_hyperlipidemia.json
# Loading module modules/mTBI.json
# Loading module modules/veteran_prostate_cancer.json
# Loading module modules/anemia___unknown_etiology.json
# Loading module modules/urinary_tract_infections.json
# Loading module modules/hypothyroidism.json
# Loading module modules/osteoarthritis.json
# Loading module modules/appendicitis.json
# Loading module modules/copd.json
# Loading module modules/contraceptive_maintenance.json
# Loading module modules/fibromyalgia.json
# Loading module modules/veteran_substance_abuse_treatment.json
# Loading module modules/veteran_lung_cancer.json
# Loading module modules/total_joint_replacement.json
# Loading module modules/prescribing_opioids_for_chronic_pain_and_treatment_of_oud.json
# Loading module modules/rheumatoid_arthritis.json
# Loading module modules/sore_throat.json
# Loading module modules/gallstones.json
# Loading module modules/bronchitis.json
# Loading module modules/spina_bifida.json
# Loading module modules/sexual_activity.json
# Loading module modules/homelessness.json
# Loading module modules/epilepsy.json
# Loading module modules/wellness_encounters.json
# Loading module modules/injuries.json
# Loading module modules/colorectal_cancer.json
# Loading module modules/med_rec.json
# Loading module modules/congestive_heart_failure.json
# Loading module modules/veteran_self_harm.json
# Loading module modules/veteran_mdd.json
# Loading module modules/lung_cancer.json
# Loading module modules/contraceptives.json
# Loading module modules/osteoporosis.json
# Loading module modules/breast_cancer.json
# Loading module modules/female_reproduction.json
# Loading module modules/veteran.json
# Loading module modules/gout.json
# Loading module modules/metabolic_syndrome_disease.json
# Loading module modules/sepsis.json
# Loading module modules/allergies.json
# Loading module modules/metabolic_syndrome_care.json
# Loading module modules/lupus.json
# Loading module modules/cystic_fibrosis.json
# Loading module modules/attention_deficit_disorder.json
# Loading module modules/dermatitis.json
# Loading module modules/food_allergies.json
# Loading module modules/mend_program.json
# Loading module modules/veteran_ptsd.json
# Loading module modules/veteran_substance_abuse_conditions.json
# Loading module modules/hypertension.json
# Running with options:
# Population: 1000
# Seed: 1771451411664
# Provider Seed:1771451411664
# Reference Time: 1771451411664
# Location: Massachusetts
# Min Age: 0
# Max Age: 17
# 3 -- Nikole56 Tromp100 (2 y/o F) Spencer, Massachusetts
# 7 -- Benny518 Feeney44 (2 y/o M) Quincy, Massachusetts
# 8 -- Tabetha269 Hoeger474 (5 y/o F) Boston, Massachusetts
# 2 -- Eldridge510 Hettinger594 (9 y/o M) Boston, Massachusetts
# 6 -- Bree992 Christiansen251 (13 y/o F) Somerville, Massachusetts
# 1 -- Dagny669 Mraz590 (13 y/o F) Sheffield, Massachusetts
# 4 -- Tangela812 Strosin214 (16 y/o F) South Yarmouth, Massachusetts
# 5 -- Bertram873 Jaskolski867 (16 y/o M) Chelmsford, Massachusetts
# 13 -- Jae222 Homenick806 (0 y/o F) Quincy, Massachusetts
# 14 -- Horacio317 Mireles421 (1 y/o M) Wilbraham, Massachusetts
# 9 -- Shyla233 Klocko335 (6 y/o F) Hopkinton, Massachusetts
# 11 -- Ariadna374 Guillen740 (4 y/o F) Westport, Massachusetts
# 16 -- Delorse592 Von197 (7 y/o F) Amesbury, Massachusetts
# 15 -- Liberty95 Lockman863 (8 y/o F) Somerville, Massachusetts
# 10 -- Cornelius968 Altenwerth646 (13 y/o M) Boston, Massachusetts
# 12 -- Bridgette172 Schoen8 (16 y/o F) Walpole, Massachusetts
# 17 -- Cristina921 Okuneva707 (14 y/o F) Fairhaven, Massachusetts
# 18 -- Mickey576 Morissette863 (15 y/o M) Gloucester, Massachusetts
# 21 -- Alan320 Volkman526 (4 y/o M) Webster, Massachusetts
# 23 -- Briana139 Shanahan202 (2 y/o F) Stoneham, Massachusetts
# 19 -- Bula88 Bernhard322 (14 y/o F) Malden, Massachusetts
# 20 -- Kyla51 Frami345 (12 y/o F) Whitman, Massachusetts
# 22 -- Olivia294 Goyette777 (9 y/o F) Barnstable, Massachusetts
# 24 -- Emelina469 Turner526 (11 y/o F) Canton, Massachusetts
# 26 -- Eloisa55 Zayas20 (4 y/o F) Cambridge, Massachusetts
# 25 -- Coretta598 Parker433 (12 y/o F) Needham, Massachusetts
# 27 -- Kerri159 Legros616 (6 y/o F) Walpole, Massachusetts
# 29 -- Jonah176 Waters156 (5 y/o M) Boston, Massachusetts
# 28 -- Dillon740 Pouros728 (6 y/o M) Oxford, Massachusetts
# 33 -- Benjamin360 Koepp521 (0 y/o M) Cambridge, Massachusetts
# 35 -- Claudio955 McKenzie376 (0 y/o M) Hardwick, Massachusetts
# 31 -- Osvaldo336 Legros616 (9 y/o M) Lynn, Massachusetts
# 36 -- Randal152 Adams676 (2 y/o M) Chicopee, Massachusetts
# 32 -- Warren653 Runolfsdottir785 (8 y/o M) Westfield, Massachusetts
# 38 -- Ivonne773 Berge125 (3 y/o F) Wilmington, Massachusetts
# 34 -- Darron84 Feest103 (9 y/o M) Arlington, Massachusetts
# 30 -- Rigoberto443 Beahan375 (15 y/o M) Dudley, Massachusetts
# 37 -- Ehtel928 Barton704 (16 y/o F) Sandwich, Massachusetts
# 40 -- Benito209 Zambrano764 (5 y/o M) Chelsea, Massachusetts
# 39 -- Dale454 Gusikowski974 (13 y/o M) Lincoln, Massachusetts
# 43 -- Leigh689 Ferry570 (2 y/o M) Somerville, Massachusetts
# 41 -- Corey514 Roob72 (8 y/o M) Watertown, Massachusetts
# 42 -- Maura912 Barrows492 (10 y/o F) Chesterfield, Massachusetts
# 47 -- Jamel269 Witting912 (3 y/o M) Dracut, Massachusetts
# 48 -- Moon129 Stracke611 (3 y/o F) Brockton, Massachusetts
# 45 -- Wilfred787 Kris249 (6 y/o M) Boston, Massachusetts
# 44 -- Mónica985 Salcedo309 (15 y/o F) Lawrence, Massachusetts
# 49 -- Roberto515 Padrón382 (3 y/o M) Amesbury, Massachusetts
# 51 -- Leda374 Bashirian201 (1 y/o F) Boston, Massachusetts
# 46 -- Vikki110 Ferry570 (15 y/o F) Lowell, Massachusetts
# 55 -- Robyn562 Medhurst46 (1 y/o F) Amherst, Massachusetts
# 52 -- Shiloh191 Bode78 (8 y/o F) Boston, Massachusetts
# 53 -- Maximo817 Wolff180 (6 y/o M) Weston, Massachusetts
# 59 -- Jarred626 O'Reilly797 (1 y/o M) Cambridge, Massachusetts
# 50 -- Earline566 Dare640 (16 y/o F) Amherst Center, Massachusetts
# 58 -- Keren761 Medhurst46 (3 y/o F) Malden, Massachusetts
# 54 -- Linh535 Erdman779 (12 y/o F) Springfield, Massachusetts
# 57 -- Shelley12 Stoltenberg489 (13 y/o F) Attleboro, Massachusetts
# 56 -- Monique148 Stehr398 (12 y/o F) Fitchburg, Massachusetts
# 61 -- Neomi684 Marks830 (4 y/o F) Somerville, Massachusetts
# 63 -- Jay242 Huels583 (0 y/o M) Mashpee, Massachusetts
# 65 -- Leonardo412 Senger904 (0 y/o M) Wareham Center, Massachusetts
# 62 -- Darrell400 Gaylord332 (5 y/o M) Springfield, Massachusetts
# 69 -- Jamie386 Robel940 (1 y/o M) Malden, Massachusetts
# 67 -- Bennett146 Jast432 (8 y/o M) Revere, Massachusetts
# 60 -- Dee580 Hills818 (16 y/o F) Lowell, Massachusetts
# 64 -- Sandy901 Walsh511 (9 y/o M) Everett, Massachusetts
# 71 -- Ethan766 Lehner980 (6 y/o M) Cambridge, Massachusetts
# 66 -- Matt836 Rutherford999 (14 y/o M) Wakefield, Massachusetts
# 68 -- Heath320 Keebler762 (13 y/o M) Millbury, Massachusetts
# 72 -- Harold594 Mohr916 (4 y/o M) Bridgewater, Massachusetts
# 70 -- Marcel580 Bogisich202 (8 y/o M) Springfield, Massachusetts
# 73 -- Mikaela760 Schneider199 (2 y/o F) Andover, Massachusetts
# 78 -- Malika385 Moore224 (0 y/o F) Medford, Massachusetts
# 75 -- Britni406 Rath779 (7 y/o F) Weymouth, Massachusetts
# 76 -- Marget728 Anderson154 (7 y/o F) Mansfield, Massachusetts
# 74 -- Brendon298 Fahey393 (11 y/o M) Boston, Massachusetts
# 77 -- Esmeralda972 Lakin515 (6 y/o F) Fall River, Massachusetts
# 82 -- Ben667 Kautzer186 (5 y/o M) Taunton, Massachusetts
# 81 -- Holley125 Olson653 (6 y/o F) Hudson, Massachusetts
# 80 -- Robt687 Gulgowski816 (7 y/o M) Worthington, Massachusetts
# 79 -- Erik495 Walter473 (16 y/o M) Heath, Massachusetts
# 85 -- Lan153 Rosenbaum794 (5 y/o F) Boston, Massachusetts
# 83 -- Arturo47 Cano735 (8 y/o M) Boston, Massachusetts
# 86 -- Edward499 Hermiston71 (1 y/o M) Billerica, Massachusetts
# 87 -- Hien98 Lubowitz58 (1 y/o F) Winchester, Massachusetts
# 90 -- Lorrine765 Ullrich385 (4 y/o F) Boston, Massachusetts
# 89 -- Elvira561 Lira652 (6 y/o F) Billerica, Massachusetts
# 92 -- Russel238 Ankunding277 (1 y/o M) Worcester, Massachusetts
# 91 -- Miquel905 Gibson10 (3 y/o M) Saugus, Massachusetts
# 93 -- Tommye961 Feest103 (1 y/o F) Chelsea, Massachusetts
# 84 -- Percy315 Hessel84 (13 y/o M) Northborough, Massachusetts
# 94 -- Nicholas495 Buckridge80 (0 y/o M) Lowell, Massachusetts
# 88 -- Eleonor544 Hyatt152 (10 y/o F) Brockton, Massachusetts
# 99 -- Anastasia959 Hamill307 (4 y/o F) Somerville, Massachusetts
# 100 -- Karol905 Casper496 (6 y/o F) Peabody, Massachusetts
# 97 -- Harrison106 Reichert620 (6 y/o M) Barnstable, Massachusetts
# 96 -- Mariam937 Romaguera67 (9 y/o F) East Longmeadow, Massachusetts
# 101 -- Glinda951 Kozey370 (2 y/o F) Peabody, Massachusetts
# 102 -- Fransisca150 Goldner995 (2 y/o F) Springfield, Massachusetts
# Waiting for threads to finish... java.util.concurrent.ThreadPoolExecutor@1a07bf6[Shutting down, pool size = 8, active threads = 8, queued tasks = 896, completed tasks = 96]
# 98 -- Noah480 Prohaska837 (15 y/o M) Truro, Massachusetts
# 95 -- Sterling124 Hettinger594 (16 y/o M) Worcester, Massachusetts
# 103 -- Cletus494 Muller251 (15 y/o M) Plymouth, Massachusetts
# 105 -- Whitney250 Hintz995 (13 y/o M) Milton, Massachusetts
# 106 -- Rhett759 Runolfsdottir785 (10 y/o M) Revere, Massachusetts
# 104 -- Carolee951 Daugherty69 (16 y/o F) Hingham, Massachusetts
# 107 -- Calandra120 Bartoletti50 (15 y/o F) Framingham, Massachusetts
# 108 -- Chas63 Dach178 (14 y/o M) Melrose, Massachusetts
# 109 -- Garland107 Zieme486 (7 y/o M) Cambridge, Massachusetts
# 113 -- Humberto482 Hane680 (6 y/o M) Wales, Massachusetts
# 110 -- Dustin31 Kulas532 (13 y/o M) Northampton, Massachusetts
# 111 -- Tyrell880 Keeling57 (13 y/o M) Worcester, Massachusetts
# 115 -- Rosa195 DuBuque211 (8 y/o F) Orange, Massachusetts
# 114 -- Charity776 Lueilwitz711 (10 y/o F) Franklin, Massachusetts
# 112 -- Oswaldo857 Ernser583 (11 y/o M) Woburn, Massachusetts
# 120 -- Percy315 Quigley282 (2 y/o M) Haverhill, Massachusetts
# 116 -- Ela754 Koch169 (12 y/o F) Brockton, Massachusetts
# 122 -- Wilford267 Mayert710 (1 y/o M) Worcester, Massachusetts
# 118 -- Rosamaria757 Schoen8 (10 y/o F) Paxton, Massachusetts
# 117 -- Marna905 Rice937 (13 y/o F) Boston, Massachusetts
# 121 -- Alease857 Bayer639 (10 y/o F) Maynard, Massachusetts
# 123 -- Fatimah228 Braun514 (11 y/o F) Clinton, Massachusetts
# 119 -- Delilah659 Hilpert278 (15 y/o F) Rockport, Massachusetts
# 124 -- Ute382 Powlowski563 (5 y/o F) Boston, Massachusetts
# 125 -- Emilia403 Limón43 (12 y/o F) Lowell, Massachusetts
# 126 -- Maxine796 Orn563 (12 y/o F) Milton, Massachusetts
# 131 -- Mohamed943 Schmeler639 (0 y/o M) Somerville, Massachusetts
# 130 -- Darryl392 Koepp521 (2 y/o M) Randolph, Massachusetts
# 128 -- Donald774 Sipes176 (10 y/o M) Milford, Massachusetts
# 132 -- Roland928 Wisozk929 (2 y/o M) Auburn, Massachusetts
# 135 -- Cedrick207 Torp761 (1 y/o M) Framingham, Massachusetts
# 127 -- Hai304 Mosciski958 (15 y/o M) Saugus, Massachusetts
# 129 -- Eldon28 Reinger292 (13 y/o M) Grafton, Massachusetts
# 133 -- Moshe758 Lang846 (6 y/o M) Bridgewater, Massachusetts
# 134 -- Harry448 Krajcik437 (6 y/o M) Blackstone, Massachusetts
# 137 -- Libbie63 Steuber698 (0 y/o F) Boston, Massachusetts
# 136 -- Marian936 West559 (4 y/o F) Harwich, Massachusetts
# 139 -- Timoteo39 Frías523 (2 y/o M) Boston, Massachusetts
# 138 -- Cira533 Bartell116 (6 y/o F) Whitman, Massachusetts
# 140 -- Trevor374 Miller503 (4 y/o M) Watertown, Massachusetts
# 143 -- Evita885 Klein929 (1 y/o F) Sterling, Massachusetts
# 142 -- Miquel905 Robel940 (6 y/o M) Belmont, Massachusetts
# 141 -- Marcos263 Powlowski563 (10 y/o M) Pembroke, Massachusetts
# 144 -- Lurlene215 Abernathy524 (7 y/o F) Boston, Massachusetts
# 148 -- Thomasena108 Buckridge80 (0 y/o F) West Concord, Massachusetts
# 145 -- Bettie175 Jenkins714 (13 y/o F) Boston, Massachusetts
# 146 -- Lenna704 Koelpin146 (11 y/o F) Worcester, Massachusetts
# 149 -- Rosalina69 McDermott739 (5 y/o F) Cambridge, Massachusetts
# 151 -- Lacy523 Roberts511 (4 y/o M) Ipswich, Massachusetts
# 150 -- Latoya8 Bins636 (12 y/o F) Lynn, Massachusetts
# 155 -- Floretta117 Paucek755 (2 y/o F) Saugus, Massachusetts
# 147 -- Magda24 Armstrong51 (16 y/o F) Mansfield, Massachusetts
# 153 -- Malik994 Bernhard322 (15 y/o M) Ashland, Massachusetts
# 157 -- Adolfo777 Kreiger457 (2 y/o M) Dedham, Massachusetts
# 152 -- Caridad510 Caldera106 (11 y/o F) Lynn, Massachusetts
# 156 -- Avery919 Willms744 (5 y/o M) Fiskdale, Massachusetts
# 154 -- Lyman173 Hammes673 (12 y/o M) Andover, Massachusetts
# 158 -- Travis723 Nienow652 (6 y/o M) Quincy, Massachusetts
# 159 -- Antonio44 Hermann103 (5 y/o M) Arlington, Massachusetts
# 160 -- Lessie363 Howe413 (8 y/o F) Clinton, Massachusetts
# 161 -- Cody889 Schuster709 (13 y/o M) Agawam, Massachusetts
# 163 -- Rex53 Zemlak964 (6 y/o M) Lakeville, Massachusetts
# 167 -- Bennett146 Hilpert278 (0 y/o M) Petersham, Massachusetts
# 162 -- Felipe97 Saldaña5 (7 y/o M) Leominster, Massachusetts
# 165 -- Dirk334 Mayert710 (2 y/o M) Peabody, Massachusetts
# 168 -- Darryl392 Abbott774 (3 y/o M) Hamilton, Massachusetts
# 166 -- Hilde556 Parker433 (3 y/o F) Boston, Massachusetts
# 171 -- Cyndy549 Schowalter414 (0 y/o F) Framingham, Massachusetts
# 169 -- Reynaldo722 Ritchie586 (5 y/o M) Boston, Massachusetts
# 164 -- Santa373 Wiegand701 (15 y/o F) New Bedford, Massachusetts
# 170 -- Keeley419 Blick895 (7 y/o F) Worcester, Massachusetts
# 176 -- Olivia294 Quezada963 (0 y/o F) Medford, Massachusetts
# 172 -- Sara501 Huel628 (6 y/o F) Medway, Massachusetts
# 174 -- Madeline975 Orn563 (7 y/o F) Dedham, Massachusetts
# 173 -- Christoper325 Hessel84 (14 y/o M) Dudley, Massachusetts
# 177 -- Zoraida650 King743 (11 y/o F) Boston, Massachusetts
# 179 -- Armand155 Nader710 (8 y/o M) Boylston, Massachusetts
# 175 -- Valeri645 Kutch271 (16 y/o F) Framingham, Massachusetts
# 178 -- Candyce305 Shields502 (13 y/o F) Bridgewater, Massachusetts
# 181 -- Nichole96 Pouros728 (2 y/o F) Medford, Massachusetts
# 182 -- Doug189 Hessel84 (6 y/o M) Boston, Massachusetts
# 180 -- Keven605 Stamm704 (10 y/o M) Brockton, Massachusetts
# 183 -- Suzette512 Prohaska837 (9 y/o F) Brookline, Massachusetts
# 185 -- Sergio619 Greenholt190 (9 y/o M) Attleboro, Massachusetts
# 184 -- Lydia759 Kirlin939 (10 y/o F) Newton, Massachusetts
# 186 -- Marcela739 Díaz674 (13 y/o F) Springfield, Massachusetts
# 188 -- Antonio44 Dávila115 (11 y/o M) Wareham, Massachusetts
# 190 -- Donnie175 Ankunding277 (1 y/o M) New Bedford, Massachusetts
# 187 -- Teodoro374 Koelpin146 (12 y/o M) Cambridge, Massachusetts
# 189 -- Jolanda321 Cronin387 (12 y/o F) Barre, Massachusetts
# 191 -- Jeri234 Bailey598 (6 y/o F) Marshfield, Massachusetts
# 194 -- Kassandra256 Effertz744 (9 y/o F) Sutton, Massachusetts
# 192 -- Bill567 Dickens475 (16 y/o M) Fitchburg, Massachusetts
# 196 -- Penney623 Cronin387 (8 y/o F) Tyngsborough, Massachusetts
# 193 -- Claud279 Klein929 (15 y/o M) Plymouth, Massachusetts
# 195 -- Bryanna1 Lindgren255 (14 y/o F) Ludlow, Massachusetts
# 197 -- Vania595 Daugherty69 (13 y/o F) Weymouth, Massachusetts
# 198 -- Aretha897 Harber290 (12 y/o F) Westfield, Massachusetts
# 199 -- Maynard46 Windler79 (16 y/o M) Walpole, Massachusetts
# 203 -- Louis204 Price929 (4 y/o M) Newton, Massachusetts
# 201 -- Janett802 Swift555 (10 y/o F) Lowell, Massachusetts
# 202 -- Roxana439 Kessler503 (15 y/o F) Needham, Massachusetts
# 200 -- Cordie578 Donnelly343 (15 y/o F) Worcester, Massachusetts
# 204 -- Gavin481 Hayes766 (5 y/o M) Milford, Massachusetts
# 205 -- Florance664 Auer97 (16 y/o F) Everett, Massachusetts
# 207 -- Rozella39 Daugherty69 (7 y/o F) Dover, Massachusetts
# 206 -- Maren639 Crist667 (12 y/o F) Tewksbury, Massachusetts
# 208 -- Aurelia213 Hilll811 (10 y/o F) Middleborough Center, Massachusetts
# 211 -- Evan94 Towne435 (4 y/o M) Beverly, Massachusetts
# 209 -- Matthew562 McGlynn426 (9 y/o M) Norwell, Massachusetts
# 212 -- Patrick786 Schoen8 (8 y/o M) Worcester, Massachusetts
# 213 -- Wendell199 Larson43 (10 y/o M) Southbridge, Massachusetts
# 214 -- Buffy238 Hegmann834 (3 y/o F) Revere, Massachusetts
# 210 -- Cherelle538 Quitzon246 (15 y/o F) Northbridge, Massachusetts
# 215 -- Raelene218 Ratke343 (6 y/o F) Pittsfield, Massachusetts
# 217 -- Tanner110 Klocko335 (12 y/o M) Boston, Massachusetts
# 216 -- Alden634 Friesen796 (13 y/o M) Westport, Massachusetts
# 219 -- Norine97 Boyle917 (9 y/o F) Boston, Massachusetts
# 218 -- Darell496 Nitzsche158 (9 y/o M) Boston, Massachusetts
# 220 -- Luigi346 Torphy630 (11 y/o M) Peabody, Massachusetts
# 223 -- Reyes140 Rosenbaum794 (3 y/o M) Malden, Massachusetts
# 221 -- Lauralee67 Kris249 (9 y/o F) Leominster, Massachusetts
# 224 -- Von197 Deckow585 (3 y/o M) Lynn, Massachusetts
# 226 -- Augusta206 Fisher429 (3 y/o F) Boston, Massachusetts
# 222 -- Denese626 Sipes176 (16 y/o F) Kingston, Massachusetts
# 231 -- Refugio197 Rolfson709 (0 y/o F) Boston, Massachusetts
# 225 -- Yvonne357 Corkery305 (8 y/o F) West Springfield, Massachusetts
# 230 -- Milagro117 Harris789 (6 y/o F) Everett, Massachusetts
# 227 -- Desmond566 Adams676 (14 y/o M) Salem, Massachusetts
# 229 -- Dennis979 Dietrich576 (12 y/o M) Boston, Massachusetts
# 228 -- Shayna64 Harber290 (16 y/o F) Mansfield, Massachusetts
# 234 -- Carol737 Nader710 (9 y/o F) Petersham, Massachusetts
# 233 -- Bryant814 Mueller846 (9 y/o M) Waltham, Massachusetts
# 232 -- Susanna279 Gutmann970 (14 y/o F) New Bedford, Massachusetts
# 236 -- Ana972 Heaney114 (7 y/o F) East Longmeadow, Massachusetts
# 237 -- Jonas187 Block661 (6 y/o M) Belmont, Massachusetts
# 235 -- Austin578 Jaskolski867 (14 y/o M) Leominster, Massachusetts
# 242 -- Claude750 Hane680 (2 y/o F) Barnstable, Massachusetts
# 239 -- Ernie189 Schoen8 (7 y/o M) Boston, Massachusetts
# 241 -- Houston994 Franecki195 (5 y/o M) Cambridge, Massachusetts
# 238 -- Cecilia788 Bravo546 (16 y/o F) Cambridge, Massachusetts
# 240 -- Rudolph554 Bradtke547 (8 y/o M) Newton, Massachusetts
# 245 -- Sigrid676 Monahan736 (3 y/o F) Boston, Massachusetts
# 243 -- Patricio639 Zaragoza109 (8 y/o M) Westfield, Massachusetts
# 246 -- Earlie274 Becker968 (3 y/o F) Westport, Massachusetts
# 244 -- Ana972 Garica503 (11 y/o F) Worcester, Massachusetts
# 248 -- Don899 Casper496 (2 y/o M) Whitinsville, Massachusetts
# 250 -- Debi992 Okuneva707 (3 y/o F) Shrewsbury, Massachusetts
# 249 -- Lyman173 Collins926 (3 y/o M) Boston, Massachusetts
# 251 -- Darrel772 Herman763 (2 y/o M) Cambridge, Massachusetts
# 247 -- Teresa94 Gutkowski940 (11 y/o F) Barnstable, Massachusetts
# 252 -- Lisha487 Hansen121 (8 y/o F) East Douglas, Massachusetts
# 254 -- Carmella421 Howe413 (6 y/o F) Haverhill, Massachusetts
# 257 -- Treasa448 Bashirian201 (4 y/o F) Middleborough, Massachusetts
# 253 -- Irwin931 Marvin195 (11 y/o M) Billerica, Massachusetts
# 256 -- Delmy607 Johnson679 (6 y/o F) Colrain, Massachusetts
# 255 -- Leif534 Funk324 (16 y/o M) Randolph, Massachusetts
# 260 -- Milo271 Marks830 (5 y/o M) Boston, Massachusetts
# 259 -- Scottie437 Gerhold939 (14 y/o M) Holyoke, Massachusetts
# 263 -- Daniele610 Konopelski743 (1 y/o F) Amesbury, Massachusetts DECEASED
# 258 -- Dario75 Raynor401 (16 y/o M) Chicopee, Massachusetts
# 262 -- Tai836 Purdy2 (9 y/o F) Sterling, Massachusetts
# 264 -- Tobias236 Stiedemann542 (8 y/o M) Randolph, Massachusetts
# 261 -- Homero668 Lovato727 (15 y/o M) Rutland, Massachusetts
# 263 -- Rufina863 West559 (3 y/o F) Amesbury, Massachusetts
# 270 -- Jeanne553 Buckridge80 (6 y/o F) Boston, Massachusetts
# 269 -- Miranda712 Raynor401 (1 y/o F) Salem, Massachusetts
# 271 -- Valorie864 Terry864 (2 y/o F) Marblehead, Massachusetts
# 265 -- Mercy752 Walker122 (13 y/o F) Boxford, Massachusetts
# 266 -- Jeramy610 Farrell962 (14 y/o M) Boston, Massachusetts
# 267 -- Brandon214 Bashirian201 (13 y/o F) Lynn, Massachusetts
# 274 -- Garland107 Schimmel440 (5 y/o M) Leominster, Massachusetts
# 273 -- Leonie332 Mitchell808 (5 y/o F) Brookline, Massachusetts
# 272 -- Roseline981 Weber641 (14 y/o F) Marlborough, Massachusetts
# 268 -- Walter473 Moore224 (12 y/o M) Bellingham, Massachusetts
# Waiting for threads to finish... java.util.concurrent.ThreadPoolExecutor@1a07bf6[Shutting down, pool size = 8, active threads = 8, queued tasks = 725, completed tasks = 267]
# 276 -- Lilla884 Kuhn96 (0 y/o F) Salem, Massachusetts
# 275 -- Dierdre747 Borer986 (6 y/o F) Chelsea, Massachusetts
# 279 -- Rudolph554 Aufderhar910 (6 y/o M) Westfield, Massachusetts
# 280 -- Bret7 Lynch190 (7 y/o M) Marlborough, Massachusetts
# 277 -- Kris249 Heller342 (11 y/o M) Everett, Massachusetts
# 278 -- Rickie717 Marks830 (11 y/o F) Carver, Massachusetts
# 281 -- Josef103 Ruecker817 (9 y/o M) Acton, Massachusetts
# 283 -- Shawanda667 Wilderman619 (10 y/o F) North Andover, Massachusetts
# 282 -- Fredrick998 Stoltenberg489 (16 y/o M) Sudbury, Massachusetts
# 284 -- Conception120 Huels583 (15 y/o F) Gloucester, Massachusetts
# 287 -- Harland508 Berge125 (5 y/o M) Worcester, Massachusetts
# 285 -- Mitchel812 Conroy74 (10 y/o M) Lynn, Massachusetts
# 288 -- Hassie51 Larson43 (8 y/o F) Worcester, Massachusetts
# 289 -- Leon728 Torp761 (9 y/o M) Winchester, Massachusetts
# 286 -- Jaymie769 Wintheiser220 (16 y/o F) Worcester, Massachusetts
# 290 -- Rueben647 Carter549 (14 y/o M) Lexington, Massachusetts
# 291 -- Daysi106 Braun514 (9 y/o F) Belmont, Massachusetts
# 293 -- María842 Parra592 (4 y/o F) Boston, Massachusetts
# 292 -- Yolanda648 Alcántar600 (7 y/o F) Haverhill, Massachusetts
# 295 -- Elvin140 Carroll471 (1 y/o M) Sheffield, Massachusetts
# 294 -- Numbers230 Corwin846 (6 y/o M) Carver, Massachusetts
# 298 -- Nathanial472 Wuckert783 (1 y/o M) Wenham, Massachusetts
# 301 -- Edmund685 Koss676 (1 y/o M) Groton, Massachusetts DECEASED
# 296 -- Elliot577 Hyatt152 (8 y/o M) Acton, Massachusetts
# 302 -- Glenn0 Hane680 (11 y/o F) Woburn, Massachusetts
# 297 -- Kristine579 Lindgren255 (13 y/o F) Marblehead, Massachusetts
# 300 -- Melinda114 Gleichner915 (14 y/o F) Fall River, Massachusetts
# 299 -- Syble581 Medhurst46 (15 y/o F) Smith Mills, Massachusetts
# 304 -- Kirstie385 Dietrich576 (0 y/o F) Ware, Massachusetts
# 303 -- Kylee806 Streich926 (3 y/o F) Fall River, Massachusetts
# 301 -- Maynard46 Schinner682 (6 y/o M) Groton, Massachusetts
# 309 -- Williams176 Tillman293 (0 y/o M) Boston, Massachusetts
# 308 -- Lin401 Schiller186 (10 y/o F) Milford, Massachusetts
# 307 -- Agustina460 Conroy74 (7 y/o F) Attleboro, Massachusetts
# 306 -- Ethelene252 Greenfelder433 (11 y/o F) Shelburne Falls, Massachusetts
# 305 -- Isaiah615 Toy286 (16 y/o M) Needham, Massachusetts
# 312 -- Maile198 Hermiston71 (7 y/o F) Lawrence, Massachusetts
# 311 -- Herb645 Frami345 (15 y/o M) Fall River, Massachusetts
# 315 -- Socorro465 Stiedemann542 (0 y/o F) Boston, Massachusetts
# 310 -- Ned189 Berge125 (13 y/o M) Plainfield, Massachusetts
# 313 -- Danica886 Schmitt836 (9 y/o F) Belmont, Massachusetts
# 314 -- Darell496 Hudson301 (13 y/o M) Plainville, Massachusetts
# 316 -- Cristobal567 Borer986 (4 y/o M) Boston, Massachusetts
# 318 -- Ariane992 McGlynn426 (8 y/o F) Billerica, Massachusetts
# 321 -- Dolly486 Rau926 (0 y/o F) Amesbury, Massachusetts
# 320 -- Santo387 Bednar518 (2 y/o M) Boston, Massachusetts
# 317 -- Fermin479 Bogisich202 (16 y/o M) Spencer, Massachusetts
# 325 -- Emery884 Considine820 (2 y/o M) Boston, Massachusetts
# 326 -- Lavera253 Jenkins714 (1 y/o F) Boston, Massachusetts
# 324 -- Yong583 Miller503 (8 y/o F) Brookfield, Massachusetts
# 319 -- Rosina706 D'Amore443 (11 y/o F) Billerica, Massachusetts
# 323 -- Santos184 Willms744 (14 y/o M) Shrewsbury, Massachusetts
# 328 -- Carrie738 Daugherty69 (3 y/o F) Great Barrington, Massachusetts
# 330 -- Óscar156 Miranda712 (3 y/o M) Rehoboth, Massachusetts
# 322 -- Sharell873 Schmidt332 (15 y/o F) Newton, Massachusetts
# 327 -- Marcellus830 Sanford861 (10 y/o M) Billerica, Massachusetts
# 329 -- Dirk334 Berge125 (8 y/o M) Falmouth, Massachusetts
# 335 -- Pete38 Mante251 (1 y/o M) Sterling, Massachusetts
# 331 -- Kevin729 Wyman904 (11 y/o M) Stoneham, Massachusetts
# 334 -- Lashonda618 Purdy2 (8 y/o F) Lynn, Massachusetts
# 332 -- Darrell400 Cummerata161 (7 y/o M) Worcester, Massachusetts
# 333 -- Danette111 Wilderman619 (9 y/o F) Rockland, Massachusetts
# 336 -- Adán600 Matos876 (8 y/o M) Boston, Massachusetts
# 337 -- Renetta865 Watsica258 (3 y/o F) Bellingham, Massachusetts
# 340 -- Shannon293 O'Conner199 (2 y/o M) Quincy, Massachusetts
# 344 -- Willy639 Kshlerin58 (0 y/o M) Pittsfield, Massachusetts
# 339 -- Roberto515 Muñiz642 (13 y/o M) Lexington, Massachusetts
# 338 -- Christinia886 Glover433 (14 y/o F) Oak Bluffs, Massachusetts
# 342 -- Jeremiah751 Langworth352 (8 y/o M) Rochester, Massachusetts
# 346 -- Markus389 Reinger292 (1 y/o M) Woburn, Massachusetts DECEASED
# 341 -- Benny518 Bernier607 (12 y/o M) Saugus, Massachusetts
# 349 -- Quinton758 MacGyver246 (0 y/o M) Malden, Massachusetts
# 343 -- Mittie376 Morissette863 (12 y/o F) Harvard, Massachusetts
# 345 -- Cecil300 Ortiz186 (13 y/o F) Lincoln, Massachusetts
# 352 -- Ty725 Mayert710 (0 y/o M) Northwest Harwich, Massachusetts
# 346 -- Irwin931 Zboncak558 (7 y/o M) Woburn, Massachusetts
# 351 -- Darren774 Adams676 (3 y/o M) Peabody, Massachusetts
# 347 -- Don899 Lubowitz58 (16 y/o M) Norwood, Massachusetts
# 353 -- Lida218 Hills818 (2 y/o F) Winthrop, Massachusetts
# 348 -- Marybelle759 Treutel973 (14 y/o F) Belchertown, Massachusetts
# 350 -- Mike230 Rowe323 (9 y/o M) South Hadley, Massachusetts
# 358 -- Leonel449 Zieme486 (1 y/o M) Weymouth, Massachusetts
# 359 -- Leon728 Ankunding277 (3 y/o M) Reading, Massachusetts
# 356 -- Daren950 Pfeffer420 (12 y/o M) Hopkinton, Massachusetts
# 355 -- Catrina144 Langworth352 (13 y/o F) Walpole, Massachusetts
# 354 -- Somer38 Runolfsson901 (13 y/o F) Walpole, Massachusetts
# 357 -- Eddie505 Zulauf375 (11 y/o M) Stoughton, Massachusetts
# 361 -- Chas63 Schuppe920 (10 y/o M) Dartmouth, Massachusetts
# 363 -- Wilson960 Brekke496 (5 y/o M) Boston, Massachusetts
# 362 -- Florentino8 Morissette863 (14 y/o M) Ashland, Massachusetts
# 360 -- Ivelisse712 Kassulke119 (15 y/o F) Ocean Grove, Massachusetts
# 367 -- Gail741 Leuschke194 (3 y/o M) Fall River, Massachusetts
# 366 -- Rolande819 Murazik203 (3 y/o F) Spencer, Massachusetts
# 365 -- Margarito178 Koch169 (12 y/o M) Worcester, Massachusetts
# 364 -- Hugo693 Stanton715 (15 y/o M) New Bedford, Massachusetts
# 369 -- Karry11 Bauch723 (8 y/o F) Barnstable, Massachusetts
# 370 -- Cleveland582 Willms744 (8 y/o M) North Attleborough, Massachusetts
# 368 -- Marquis364 Ruecker817 (12 y/o M) Marlborough, Massachusetts
# 373 -- John539 Moore224 (3 y/o M) Swansea, Massachusetts
# 372 -- Lane844 Haley279 (11 y/o M) Malden, Massachusetts
# 374 -- Waldo53 Herman763 (1 y/o M) Winthrop, Massachusetts
# 376 -- Deandre599 Glover433 (3 y/o M) Fall River, Massachusetts
# 378 -- Monte325 Schiller186 (3 y/o M) Hingham, Massachusetts
# 371 -- Edgardo196 Dietrich576 (15 y/o M) Somerville, Massachusetts
# 380 -- Rueben647 Erdman779 (2 y/o M) Dighton, Massachusetts
# 375 -- Blondell454 Bailey598 (16 y/o F) Chicopee, Massachusetts
# 379 -- Linwood526 Reinger292 (13 y/o M) Sudbury, Massachusetts
# 377 -- Tomás404 Quiñones183 (15 y/o M) Boston, Massachusetts
# 381 -- Logan497 Rath779 (16 y/o M) Boston, Massachusetts
# 382 -- Marylynn944 Glover433 (11 y/o F) Provincetown, Massachusetts
# 385 -- Cecil300 Adams676 (0 y/o F) Canton, Massachusetts
# 386 -- Isaiah615 Heidenreich818 (0 y/o M) Boston, Massachusetts
# 383 -- Marianna323 Klein929 (9 y/o F) Malden, Massachusetts
# 384 -- Stan246 Bergnaum523 (11 y/o M) Boston, Massachusetts
# 388 -- Hobert364 Leffler128 (2 y/o M) Chelsea, Massachusetts
# 390 -- Cinderella355 Rempel203 (1 y/o F) Gloucester, Massachusetts
# 391 -- Todd315 Beatty507 (1 y/o M) Lynn, Massachusetts
# 389 -- Nolan344 Bahringer146 (3 y/o M) Saugus, Massachusetts
# 387 -- Jonathon205 Huel628 (5 y/o M) Lawrence, Massachusetts
# 396 -- Josef103 Ebert178 (0 y/o M) Worcester, Massachusetts
# 397 -- Walton167 O'Reilly797 (3 y/o M) Boston, Massachusetts
# 395 -- Augustina561 Dibbert990 (10 y/o F) East Longmeadow, Massachusetts
# 394 -- Alejandro916 Kihn564 (9 y/o M) Weymouth, Massachusetts
# 392 -- Ricky354 Tillman293 (12 y/o M) Reading, Massachusetts
# 393 -- Candance389 Blanda868 (13 y/o F) Boston, Massachusetts
# 402 -- Charlie254 D'Amore443 (0 y/o M) Cochituate, Massachusetts
# 398 -- Alycia285 Zieme486 (15 y/o F) Medford, Massachusetts
# 400 -- Collen405 Ferry570 (11 y/o F) Boston, Massachusetts
# 399 -- Christinia886 Hamill307 (14 y/o F) Boston, Massachusetts
# 403 -- Sara501 Conn188 (3 y/o F) Worcester, Massachusetts
# 405 -- Jerlene697 O'Hara248 (2 y/o F) Fall River, Massachusetts
# 401 -- Colton403 Block661 (14 y/o M) Framingham, Massachusetts
# 404 -- Vicente970 Shanahan202 (9 y/o M) Dartmouth, Massachusetts
# 407 -- Lyle846 Kunde533 (2 y/o M) Quincy, Massachusetts
# 409 -- Latricia419 Schroeder447 (1 y/o F) Bridgewater, Massachusetts
# 410 -- Bernard308 Jast432 (3 y/o M) Lynn, Massachusetts
# 406 -- Brendon298 Labadie908 (7 y/o M) Brookline, Massachusetts
# 408 -- Grant908 Weimann465 (9 y/o M) Wellfleet, Massachusetts
# 411 -- Novella551 Bechtelar572 (6 y/o F) Pocasset, Massachusetts
# 413 -- Dana512 Reichert620 (2 y/o M) Boston, Massachusetts
# 416 -- Ginette140 Harber290 (4 y/o F) Lawrence, Massachusetts
# 414 -- Lucius907 Feil794 (12 y/o M) Ipswich, Massachusetts
# 419 -- Mohammad578 Jacobi462 (1 y/o M) Springfield, Massachusetts
# 412 -- Jacquelynn434 Treutel973 (16 y/o F) Plymouth, Massachusetts
# 418 -- Twyla619 Jakubowski832 (11 y/o F) Falmouth, Massachusetts
# 420 -- Domenic627 Rogahn59 (2 y/o M) Cochituate, Massachusetts
# 415 -- Sergio619 Ondricka197 (15 y/o M) Wellesley, Massachusetts
# 417 -- Fermin479 Stanton715 (13 y/o M) Boston, Massachusetts
# 422 -- Ester635 Gulgowski816 (3 y/o F) South Deerfield, Massachusetts
# 424 -- Caitlin552 Smitham825 (1 y/o F) Framingham, Massachusetts
# 421 -- Jeffery551 Ebert178 (11 y/o M) Uxbridge, Massachusetts
# 425 -- Marna905 Feil794 (2 y/o F) Methuen, Massachusetts
# 423 -- Chanell45 Hoeger474 (7 y/o F) Foxborough, Massachusetts
# 429 -- Antoinette709 Walsh511 (2 y/o F) Springfield, Massachusetts
# 428 -- Freddie621 Skiles927 (5 y/o M) North Attleborough, Massachusetts
# 426 -- Rene434 Stroman228 (10 y/o M) Methuen, Massachusetts
# 431 -- Conchita9 Chávez927 (2 y/o F) Boston, Massachusetts
# 427 -- Darin74 Parker433 (13 y/o M) Attleboro, Massachusetts
# 430 -- Hallie315 Herman763 (12 y/o F) Boston, Massachusetts
# 433 -- Ling534 Wisozk929 (5 y/o F) Fall River, Massachusetts
# 434 -- Pasquale620 Kulas532 (4 y/o M) East Falmouth, Massachusetts
# 432 -- María del Carmen27 Garay400 (13 y/o F) Leicester, Massachusetts
# 435 -- Hal307 O'Reilly797 (9 y/o M) Framingham, Massachusetts
# 436 -- Freeman822 Borer986 (3 y/o M) Brockton, Massachusetts
# 437 -- Ardella559 Dooley940 (16 y/o F) Cambridge, Massachusetts
# 439 -- Nicky270 Predovic534 (10 y/o M) Athol, Massachusetts
# 438 -- Sueann178 Mann644 (10 y/o F) Boston, Massachusetts
# 441 -- August363 Koch169 (10 y/o M) Billerica, Massachusetts
# 440 -- Benny518 Sauer652 (10 y/o M) Lynn, Massachusetts
# 443 -- Gil594 Keeling57 (10 y/o M) Waltham, Massachusetts
# 442 -- Audry167 McDermott739 (14 y/o F) Westfield, Massachusetts
# 444 -- Ricky354 Purdy2 (15 y/o M) Springfield, Massachusetts
# 447 -- Lisandra920 Harvey63 (4 y/o F) Boston, Massachusetts
# 446 -- Mel236 Collier206 (6 y/o M) Holbrook, Massachusetts
# 449 -- Ned189 Boyle917 (5 y/o M) Franklin, Massachusetts
# 448 -- Desmond566 Gusikowski974 (6 y/o M) Northampton, Massachusetts
# 445 -- Allan198 Cummings51 (11 y/o M) Melrose, Massachusetts DECEASED
# 450 -- Jude172 Bashirian201 (8 y/o F) Quincy, Massachusetts
# 451 -- Raúl937 Serrano248 (10 y/o M) Nantucket, Massachusetts
# 453 -- Andrew29 Schumm995 (2 y/o M) Cambridge, Massachusetts
# 452 -- Dani520 Rosenbaum794 (5 y/o F) Granby, Massachusetts
# 455 -- Gabriel934 Swift555 (8 y/o M) Dover, Massachusetts
# 458 -- Renaldo199 Turner526 (10 y/o M) Randolph, Massachusetts
# 460 -- Rhona164 Fay398 (3 y/o F) Revere, Massachusetts
# 445 -- Malcolm243 Heidenreich818 (12 y/o M) Melrose, Massachusetts
# 454 -- Clark193 Mayer370 (16 y/o M) Mansfield, Massachusetts
# 457 -- Antonio44 Canales95 (11 y/o M) Worcester, Massachusetts
# 459 -- Bradford382 Casper496 (10 y/o M) North Reading, Massachusetts
# 456 -- Jorge203 Luna60 (16 y/o M) Dedham, Massachusetts
# 462 -- Dominica520 Yundt842 (2 y/o F) Falmouth, Massachusetts
# 464 -- Efrain317 Ullrich385 (0 y/o M) North Reading, Massachusetts
# 465 -- Joanna347 Moen819 (1 y/o F) Pittsfield, Massachusetts
# 461 -- Kathi607 Kuhic920 (13 y/o F) Marlborough, Massachusetts
# 467 -- Ricarda574 Turcotte120 (7 y/o F) Leicester, Massachusetts
# 463 -- Eda506 Boyle917 (14 y/o F) Falmouth, Massachusetts
# 466 -- Tyrell880 Schumm995 (14 y/o M) Falmouth, Massachusetts
# 468 -- Ruben688 Donnelly343 (13 y/o M) Boston, Massachusetts
# 469 -- Noel608 Rutherford999 (15 y/o M) Sagamore, Massachusetts
# 471 -- Jc393 Kub800 (5 y/o M) New Bedford, Massachusetts
# 470 -- Timothy142 Nicolas769 (7 y/o F) Lawrence, Massachusetts
# 474 -- Jacob959 Stokes453 (16 y/o M) Upton, Massachusetts
# 472 -- Renae431 Ondricka197 (8 y/o F) Truro, Massachusetts
# 477 -- Marcel580 Stamm704 (0 y/o M) Attleboro, Massachusetts
# 475 -- Keneth579 Brekke496 (16 y/o M) Westwood, Massachusetts
# 476 -- Harriette8 Stehr398 (4 y/o F) Wilmington, Massachusetts
# 473 -- Roma9 Oberbrunner298 (12 y/o F) Lowell, Massachusetts
# 479 -- Marshall526 Bradtke547 (5 y/o M) New Bedford, Massachusetts
# 480 -- Bailey598 Feeney44 (2 y/o F) Bedford, Massachusetts
# 485 -- Dorie139 Metz686 (0 y/o F) Taunton, Massachusetts
# 484 -- Rolland302 Nikolaus26 (2 y/o M) Haverhill, Massachusetts
# 481 -- Shonta375 Kuphal363 (8 y/o F) South Yarmouth, Massachusetts
# 478 -- Pricilla716 Koch169 (12 y/o F) Walpole, Massachusetts
# 486 -- Randal152 Jacobi462 (5 y/o M) Lawrence, Massachusetts
# 483 -- Buster609 Sanford861 (13 y/o M) Peabody, Massachusetts
# 487 -- Zachary28 Konopelski743 (16 y/o M) Springfield, Massachusetts
# 482 -- Isidro558 Bins636 (14 y/o M) Taunton, Massachusetts
# 488 -- Jarrod316 Harber290 (11 y/o M) Boston, Massachusetts
# 489 -- Stefan297 Sauer652 (13 y/o M) Lowell, Massachusetts
# 490 -- Toshia520 Padberg411 (5 y/o F) Woburn, Massachusetts
# Waiting for threads to finish... java.util.concurrent.ThreadPoolExecutor@1a07bf6[Shutting down, pool size = 8, active threads = 8, queued tasks = 505, completed tasks = 487]
# 491 -- Brain142 Hammes673 (6 y/o M) Douglas, Massachusetts
# 495 -- Vernetta697 Hettinger594 (2 y/o F) Rochester, Massachusetts
# 493 -- Lyle846 VonRueden376 (7 y/o M) Springfield, Massachusetts
# 492 -- Thanh759 Hane680 (8 y/o F) Boston, Massachusetts
# 497 -- Otto672 Nolan344 (0 y/o M) Cambridge, Massachusetts
# 494 -- Newton741 Bradtke547 (14 y/o M) Arlington, Massachusetts
# 501 -- Emile522 Feest103 (0 y/o M) Everett, Massachusetts
# 496 -- Dante562 Bins636 (5 y/o M) Wakefield, Massachusetts
# 498 -- Anderson154 O'Hara248 (8 y/o M) Danvers, Massachusetts
# 500 -- Katelyn962 Altenwerth646 (9 y/o F) Brockton, Massachusetts
# 499 -- Lawrence741 Hegmann834 (11 y/o F) Fall River, Massachusetts
# 503 -- Manual570 Maggio310 (2 y/o M) Medford, Massachusetts
# 502 -- Stacy406 Carroll471 (10 y/o F) Lawrence, Massachusetts
# 507 -- Kasey569 Farrell962 (4 y/o M) Waltham, Massachusetts
# 506 -- Amanda238 Baumbach677 (5 y/o F) Lynn, Massachusetts
# 510 -- María del Carmen27 Calvillo618 (3 y/o F) Salem, Massachusetts
# 509 -- Melissa844 Grant908 (8 y/o F) East Longmeadow, Massachusetts
# 508 -- Felipe97 Schimmel440 (8 y/o M) Quincy, Massachusetts
# 504 -- Shanika235 Weber641 (16 y/o F) Boston, Massachusetts
# 505 -- Cherilyn114 Windler79 (16 y/o F) Chatham, Massachusetts
# 511 -- Millard193 Emmerich580 (6 y/o M) Weymouth, Massachusetts
# 517 -- Ocie984 Ankunding277 (1 y/o F) New Bedford, Massachusetts
# 513 -- Alyce744 Leannon79 (11 y/o F) Amherst, Massachusetts
# 512 -- Florencia449 Gómez206 (16 y/o F) Lowell, Massachusetts
# 515 -- Aldo414 Wilkinson796 (8 y/o M) Barnstable, Massachusetts
# 518 -- Florentino8 Bahringer146 (7 y/o M) Lynn, Massachusetts
# 519 -- Tobias236 Towne435 (3 y/o M) Peabody, Massachusetts
# 514 -- Kelley882 Schmeler639 (16 y/o M) Waltham, Massachusetts
# 516 -- Lisandra920 Cummerata161 (14 y/o F) Amherst, Massachusetts
# 521 -- Isaac321 Okuneva707 (1 y/o M) Harvard, Massachusetts
# 522 -- Jerome176 Bergstrom287 (1 y/o M) Randolph, Massachusetts
# 520 -- Wanita14 Grimes165 (14 y/o F) Scituate, Massachusetts
# 527 -- Laurena366 Cronin387 (1 y/o F) Windsor, Massachusetts
# 524 -- Burt293 Ryan260 (5 y/o M) East Harwich, Massachusetts
# 525 -- Troy560 Durgan499 (8 y/o M) Northfield, Massachusetts
# 523 -- Zenaida56 McCullough561 (11 y/o F) Wayland, Massachusetts
# 529 -- Fleta652 Bruen238 (4 y/o F) Spencer, Massachusetts
# 528 -- Alejandro916 Ryan260 (12 y/o M) Rochester, Massachusetts
# 526 -- Orval846 Grant908 (14 y/o M) Springfield, Massachusetts
# 530 -- Elmo857 Kub800 (4 y/o M) Boston, Massachusetts
# 532 -- Sylvia544 Weissnat378 (4 y/o F) Haverhill, Massachusetts
# 531 -- Bertram873 Nitzsche158 (11 y/o M) Marblehead, Massachusetts
# 533 -- Breann988 Schneider199 (11 y/o F) Lynn, Massachusetts
# 538 -- Cassidy160 Friesen796 (0 y/o F) Brockton, Massachusetts
# 536 -- Haley279 Bogan287 (7 y/o F) Northampton, Massachusetts
# 535 -- Ailene520 Williamson769 (14 y/o F) Leominster, Massachusetts
# 537 -- Millard193 Marks830 (11 y/o M) Andover, Massachusetts
# 541 -- Wilson960 Towne435 (3 y/o M) Whitman, Massachusetts
# 540 -- Ward668 Green467 (3 y/o M) Chelsea, Massachusetts
# 534 -- Princess223 Hansen121 (16 y/o F) Tewksbury, Massachusetts
# 542 -- Sierra982 Berge125 (11 y/o F) Malden, Massachusetts
# 539 -- Carlos172 Daniel959 (15 y/o M) Stoughton, Massachusetts
# 545 -- Deangelo7 Rutherford999 (4 y/o M) Newton, Massachusetts
# 547 -- Prince887 Kovacek682 (1 y/o M) Williamstown, Massachusetts
# 546 -- Delinda651 Roberts511 (9 y/o F) Worcester, Massachusetts
# 544 -- Catina822 Moen819 (12 y/o F) Tewksbury, Massachusetts
# 543 -- Clarence5 Thiel172 (17 y/o F) Brookline, Massachusetts
# 551 -- Bernie827 Franecki195 (9 y/o M) Braintree, Massachusetts
# 548 -- Christian753 Schmidt332 (11 y/o F) Andover, Massachusetts
# 552 -- Tawana222 Tillman293 (1 y/o F) Newburyport, Massachusetts
# 549 -- Earle679 Deckow585 (15 y/o M) North Attleborough, Massachusetts
# 550 -- Shannon293 Glover433 (11 y/o M) Yarmouth, Massachusetts
# 555 -- Eleonora961 Rosenbaum794 (0 y/o F) Whitinsville, Massachusetts
# 559 -- Yulanda554 Stoltenberg489 (0 y/o F) Billerica, Massachusetts
# 553 -- Callie226 Bechtelar572 (8 y/o F) Cohasset, Massachusetts
# 554 -- Anisa442 Fritsch593 (11 y/o F) Boston, Massachusetts
# 560 -- Shantell717 Kris249 (4 y/o F) Duxbury, Massachusetts
# 557 -- Rudy520 Nolan344 (9 y/o M) Palmer, Massachusetts
# 562 -- Earl438 Toy286 (2 y/o M) Northborough, Massachusetts
# 556 -- Romelia905 Lowe577 (11 y/o F) Duxbury, Massachusetts
# 561 -- Nakia544 Yost751 (15 y/o F) Chelmsford, Massachusetts
# 558 -- Stephine916 Wiegand701 (14 y/o F) Longmeadow, Massachusetts
# 564 -- Lue764 Konopelski743 (3 y/o F) Georgetown, Massachusetts
# 565 -- Takako793 Hirthe744 (8 y/o F) Boston, Massachusetts
# 566 -- Hoyt490 Parker433 (7 y/o M) Springfield, Massachusetts
# 563 -- Boyd728 Schoen8 (10 y/o M) Lexington, Massachusetts
# 570 -- Jeremy766 Gerlach374 (7 y/o M) Mansfield Center, Massachusetts
# 568 -- Florance664 Runolfsdottir785 (9 y/o F) Canton, Massachusetts
# 567 -- Jc393 Herman763 (16 y/o M) Framingham, Massachusetts
# 573 -- Roscoe437 Hyatt152 (2 y/o M) Plymouth, Massachusetts
# 571 -- Jacklyn830 Schaefer657 (10 y/o F) Marshfield, Massachusetts
# 569 -- Lorina403 Koss676 (16 y/o F) Belmont, Massachusetts
# 572 -- Daniela614 Ponce361 (6 y/o F) Peabody, Massachusetts
# 576 -- Gail741 Bechtelar572 (14 y/o M) Somerville, Massachusetts
# 574 -- Pablo44 Mosciski958 (16 y/o M) Springfield, Massachusetts
# 575 -- Lawanda300 Orn563 (14 y/o F) Sandisfield, Massachusetts
# 577 -- Gabriel934 Medhurst46 (12 y/o M) East Bridgewater, Massachusetts
# 578 -- Emelda84 Gleason633 (13 y/o F) Sharon, Massachusetts
# 581 -- Gennie418 Kessler503 (9 y/o F) Pittsfield, Massachusetts
# 579 -- Arlen68 Emard19 (10 y/o M) Watertown, Massachusetts
# 583 -- Pennie519 Streich926 (1 y/o F) Holyoke, Massachusetts
# 584 -- Scottie437 Christiansen251 (0 y/o M) Arlington, Massachusetts
# 588 -- Yu876 Hintz995 (1 y/o F) South Hadley, Massachusetts
# 580 -- Bruna504 Schoen8 (16 y/o F) Danvers, Massachusetts
# 586 -- Kizzie166 Marvin195 (6 y/o F) Fitchburg, Massachusetts
# 582 -- Marth98 Kling921 (15 y/o F) Plymouth, Massachusetts
# 585 -- Ernesto186 Piña753 (13 y/o M) Pembroke, Massachusetts
# 587 -- Judi176 Lindgren255 (14 y/o F) Quincy, Massachusetts
# 591 -- Cathrine584 Purdy2 (5 y/o F) Boston, Massachusetts
# 589 -- Rosario163 Nader710 (13 y/o M) Dracut, Massachusetts
# 590 -- María Soledad68 Otero621 (13 y/o F) Raynham, Massachusetts
# 593 -- Shanae34 Stoltenberg489 (4 y/o F) Holliston, Massachusetts
# 596 -- Meagan221 Schowalter414 (0 y/o F) Haverhill, Massachusetts
# 592 -- Tanisha724 Lehner980 (5 y/o F) Worcester, Massachusetts
# 595 -- Leandra549 Beahan375 (2 y/o F) Worcester, Massachusetts
# 594 -- Genie948 Reichel38 (7 y/o F) Boston, Massachusetts
# 597 -- Robt687 Rau926 (2 y/o M) South Lancaster, Massachusetts
# 602 -- Daniela614 Hoppe518 (1 y/o F) Boston, Massachusetts
# 599 -- Torri758 Ziemann98 (6 y/o F) Randolph, Massachusetts
# 600 -- Delbert384 Sauer652 (8 y/o M) Brockton, Massachusetts
# 603 -- Kasandra729 Schumm995 (2 y/o F) Worcester, Massachusetts
# 606 -- Lenora887 Rolfson709 (0 y/o F) Lunenburg, Massachusetts
# 601 -- Dominic463 Brakus656 (13 y/o M) Dracut, Massachusetts
# 598 -- Theodora872 Pollich983 (15 y/o F) Hingham, Massachusetts
# 608 -- Dolores502 Volkman526 (0 y/o F) Medford, Massachusetts
# 607 -- Kandace783 Adams676 (8 y/o F) Arlington, Massachusetts
# 604 -- Nichelle912 Lockman863 (16 y/o F) Falmouth, Massachusetts
# 605 -- Jaime666 Orn563 (15 y/o F) Taunton, Massachusetts
# 610 -- Patrica776 Larkin917 (9 y/o F) Marshfield, Massachusetts
# 612 -- Aldo414 Mohr916 (4 y/o M) Brockton, Massachusetts
# 613 -- Pete38 Brekke496 (3 y/o M) Cambridge, Massachusetts
# 609 -- Jesús825 Carrasquillo418 (15 y/o M) Southwick, Massachusetts
# 611 -- Claude750 Braun514 (16 y/o M) Chicopee, Massachusetts
# 616 -- Maximo817 McClure239 (1 y/o M) Westborough, Massachusetts
# 614 -- Laverne101 Kemmer137 (8 y/o M) Franklin, Massachusetts
# 617 -- Christine147 Moen819 (4 y/o F) Leominster, Massachusetts
# 620 -- Berenice603 Hirthe744 (2 y/o F) Boston, Massachusetts
# 615 -- Lawana430 Reichert620 (10 y/o F) Boston, Massachusetts
# 619 -- Gregorio366 Hermiston71 (5 y/o M) Chelsea, Massachusetts
# 622 -- Quinn173 Klein929 (0 y/o M) Harwich, Massachusetts
# 618 -- Danilo179 Ortiz186 (14 y/o M) Cambridge, Massachusetts
# 621 -- Daron260 King743 (8 y/o M) Ashburnham, Massachusetts
# 625 -- Tressa150 Hahn503 (2 y/o F) Gardner, Massachusetts
# ...
# 755 -- Lorraine478 Botsford977 (4 y/o F) East Sandwich, Massachusetts
# 757 -- Terri848 Okuneva707 (4 y/o F) Boston, Massachusetts
# 752 -- Dann525 Wunsch504 (15 y/o F) Fall River, Massachusetts
# Waiting for threads to finish... java.util.concurrent.ThreadPoolExecutor@1a07bf6[Shutting down, pool size = 8, active threads = 8, queued tasks = 241, completed tasks = 751]
# 756 -- Aleida76 DuBuque211 (6 y/o F) Lowell, Massachusetts
# 759 -- Felton646 Simonis280 (8 y/o M) Brockton, Massachusetts
# 754 -- Santiago500 Alvarado520 (14 y/o M) Westfield, Massachusetts
# 758 -- Alisa860 Wyman904 (13 y/o F) Andover, Massachusetts
# 762 -- Eddy900 Dietrich576 (2 y/o M) Dartmouth, Massachusetts
# 760 -- Renaldo199 McCullough561 (13 y/o M) Burlington, Massachusetts
# 761 -- Harrison106 McGlynn426 (14 y/o M) Woburn, Massachusetts
# 763 -- Refugio197 Nicolas769 (9 y/o F) Boston, Massachusetts
# 767 -- Gail741 Boehm581 (2 y/o M) Everett, Massachusetts
# 769 -- Maisie206 Williamson769 (4 y/o F) Fitchburg, Massachusetts
# 764 -- Chris95 Balistreri607 (15 y/o F) Newton, Massachusetts
# 766 -- Christine147 Leffler128 (6 y/o F) Boston, Massachusetts
# 765 -- Thurman577 King743 (13 y/o M) Barnstable, Massachusetts
# 768 -- Alena861 Goyette777 (14 y/o F) Beverly, Massachusetts
# 773 -- Nelly786 Smitham825 (1 y/o F) Medway, Massachusetts
# 771 -- Drema139 Luettgen772 (6 y/o F) Plymouth, Massachusetts
# 770 -- Lakia502 Boehm581 (14 y/o F) Billerica, Massachusetts
# 774 -- Temple691 Durgan499 (7 y/o F) Salisbury, Massachusetts
# 776 -- Jeanmarie510 Schiller186 (5 y/o F) Boston, Massachusetts
# 777 -- Treena759 Corkery305 (5 y/o F) North Amherst, Massachusetts
# 775 -- Esperanza675 Ledesma253 (7 y/o F) Boston, Massachusetts
# 772 -- Hollie21 Dicki44 (16 y/o F) Framingham, Massachusetts
# 778 -- Dallas143 Boyle917 (11 y/o M) Dartmouth, Massachusetts
# 779 -- Duane703 Padberg411 (7 y/o M) Concord, Massachusetts
# 783 -- Alejandro916 Ruecker817 (0 y/o M) Boston, Massachusetts
# 781 -- Rowena386 Walter473 (3 y/o F) Melrose, Massachusetts
# 784 -- Rashida558 Prosacco716 (4 y/o F) Boston, Massachusetts
# 782 -- Katharina121 Strosin214 (9 y/o F) Middleborough Center, Massachusetts
# 780 -- Lakiesha286 Klocko335 (13 y/o F) Foxborough, Massachusetts
# 786 -- Therese102 Lebsack687 (3 y/o F) Gardner, Massachusetts
# 785 -- Cherelle538 Keebler762 (8 y/o F) Brookline, Massachusetts
# 789 -- Clint766 Goldner995 (1 y/o M) Wareham Center, Massachusetts
# 788 -- Rueben647 Cole117 (9 y/o M) Boston, Massachusetts
# 790 -- Neal874 Kilback373 (3 y/o M) Watertown, Massachusetts
# 791 -- Matha641 Kuhic920 (3 y/o F) Springfield, Massachusetts
# 787 -- Damaris45 Schuppe920 (12 y/o F) Charlemont, Massachusetts
# 794 -- Lilian665 Purdy2 (0 y/o F) Springfield, Massachusetts
# 792 -- Ty725 Kovacek682 (10 y/o M) Everett, Massachusetts
# 797 -- Delicia67 Feest103 (1 y/o F) Arlington, Massachusetts
# 795 -- Monserrate4 Cassin499 (7 y/o F) Fall River, Massachusetts
# 793 -- Brock407 Kautzer186 (11 y/o M) Quincy, Massachusetts
# 798 -- Ross213 Cummerata161 (1 y/o M) Boston, Massachusetts
# 796 -- Loria303 Stokes453 (9 y/o F) Plymouth, Massachusetts
# 799 -- Maximo817 Harvey63 (5 y/o M) Boston, Massachusetts
# 803 -- Lucio648 Hickle134 (2 y/o M) Needham, Massachusetts
# 802 -- Anisa442 Hessel84 (6 y/o F) Chelsea, Massachusetts
# 804 -- Alvaro283 Block661 (2 y/o M) Chicopee, Massachusetts
# 805 -- Maynard46 Brekke496 (4 y/o M) Fall River, Massachusetts
# 801 -- Stan246 Kohler843 (14 y/o M) Peabody, Massachusetts
# 808 -- Brent147 Gulgowski816 (0 y/o M) Framingham, Massachusetts
# 800 -- Enola75 Ledner144 (15 y/o F) Melrose, Massachusetts
# 810 -- Buena501 Grady603 (1 y/o F) Mashpee, Massachusetts
# 806 -- Tamra871 Kessler503 (8 y/o F) Avon, Massachusetts
# 812 -- Albert312 Tillman293 (2 y/o F) Medford, Massachusetts
# 813 -- Quentin28 Morar593 (8 y/o M) Somerville, Massachusetts
# 809 -- Alec433 Ondricka197 (8 y/o M) Waltham, Massachusetts
# 807 -- Soledad678 Samaniego616 (13 y/o F) Malden, Massachusetts
# 811 -- Olen518 Gleason633 (10 y/o M) Methuen, Massachusetts
# 814 -- Hisako109 Gusikowski974 (4 y/o F) Ludlow, Massachusetts
# 816 -- Erasmo545 Gerhold939 (0 y/o M) Adams, Massachusetts
# 818 -- Stewart672 Price929 (1 y/o M) Agawam, Massachusetts
# 815 -- Bernadette714 Medhurst46 (5 y/o F) Reading, Massachusetts
# 819 -- Arline53 Shanahan202 (2 y/o F) Easton, Massachusetts
# 824 -- Tanja584 Walter473 (4 y/o F) Holyoke, Massachusetts
# 820 -- Lonna614 Blanda868 (4 y/o F) Boston, Massachusetts
# 817 -- Jordan900 Vandervort697 (12 y/o M) Springfield, Massachusetts
# 823 -- Bradly656 Crooks415 (7 y/o M) Dennis, Massachusetts
# 822 -- Roberto515 Baeza53 (6 y/o M) Revere, Massachusetts
# 821 -- Marcellus830 Auer97 (16 y/o M) Chicopee, Massachusetts
# 825 -- Scottie437 Dickens475 (6 y/o F) Harwich, Massachusetts
# 827 -- José Luis472 Salcido465 (2 y/o M) Middleborough Center, Massachusetts
# 826 -- Heike726 Abbott774 (7 y/o F) Braintree, Massachusetts
# 829 -- Marvin195 Kirlin939 (5 y/o M) Chelmsford, Massachusetts
# 833 -- Spencer878 Aufderhar910 (1 y/o M) Brockton, Massachusetts
# 831 -- Earnest658 Greenfelder433 (6 y/o M) Grafton, Massachusetts
# 828 -- Greg949 Feest103 (13 y/o M) North Attleborough, Massachusetts
# 830 -- Samuel331 Kohler843 (10 y/o M) Newburyport, Massachusetts
# 835 -- Charisse42 Dietrich576 (1 y/o F) Taunton, Massachusetts
# 837 -- Jordan900 Adams676 (2 y/o M) Brockton, Massachusetts
# 838 -- Octavio643 Schroeder447 (0 y/o M) Falmouth, Massachusetts
# 836 -- Tatiana738 Bradtke547 (4 y/o F) Westborough, Massachusetts
# 834 -- Chance908 Simonis280 (14 y/o M) Hingham, Massachusetts
# 832 -- Verónica383 Vera718 (16 y/o F) Boston, Massachusetts
# 840 -- Josef103 Kiehn525 (4 y/o M) Boston, Massachusetts
# 843 -- Ana Luisa894 Irizarry542 (3 y/o F) Braintree, Massachusetts
# 839 -- Glenn0 Kilback373 (13 y/o M) Gloucester, Massachusetts
# 842 -- Jessenia588 McDermott739 (6 y/o F) Reading, Massachusetts
# 841 -- Mahalia897 Huels583 (16 y/o F) Plymouth, Massachusetts
# 845 -- Jared66 Schulist381 (8 y/o M) Weston, Massachusetts
# 847 -- Keven605 Nienow652 (5 y/o M) Hanover, Massachusetts
# 846 -- Angelyn934 Romaguera67 (8 y/o F) Cambridge, Massachusetts
# 844 -- Kareem959 Rosenbaum794 (15 y/o M) Weymouth, Massachusetts
# 849 -- Hung902 Cronin387 (7 y/o M) Belmont, Massachusetts
# 848 -- Solomon675 Sanford861 (14 y/o M) Dover, Massachusetts
# 850 -- Thomas756 Strosin214 (8 y/o M) Somerville, Massachusetts
# 851 -- Fernando603 Moen819 (6 y/o M) Haverhill, Massachusetts
# 854 -- Michel472 Terry864 (3 y/o F) Somerville, Massachusetts
# 852 -- Wesley533 Abernathy524 (6 y/o M) Boston, Massachusetts
# 853 -- Titus37 Hickle134 (13 y/o M) Arlington, Massachusetts
# 859 -- Ronny764 Conroy74 (4 y/o M) Falmouth, Massachusetts
# 856 -- Else33 Ritchie586 (11 y/o F) Westfield, Massachusetts
# 855 -- Candyce305 Feest103 (15 y/o F) Groton, Massachusetts
# 860 -- Chad48 Homenick806 (5 y/o M) Westborough, Massachusetts
# 857 -- Isabela97 Hurtado459 (16 y/o F) Holyoke, Massachusetts
# 858 -- Estela596 Goyette777 (16 y/o F) Maynard, Massachusetts
# 862 -- Randolph418 Rolfson709 (6 y/o M) Woburn, Massachusetts
# 861 -- Palmer257 Emmerich580 (6 y/o M) Everett, Massachusetts
# 868 -- Sherman440 Reilly981 (0 y/o M) Everett, Massachusetts
# 864 -- Otis335 Keeling57 (15 y/o M) Newburyport, Massachusetts
# 866 -- Elza246 Lakin515 (3 y/o F) Palmer, Massachusetts
# 867 -- Roseanne877 Gorczany269 (8 y/o F) Wilbraham, Massachusetts
# 863 -- Vita624 Lang846 (16 y/o F) Sutton, Massachusetts
# 865 -- Collin529 Moen819 (13 y/o M) South Dennis, Massachusetts
# 871 -- Marjory382 Kunze215 (0 y/o F) Millbury, Massachusetts
# 870 -- Dustin31 Ondricka197 (2 y/o M) Fitchburg, Massachusetts
# 869 -- Taylor21 McClure239 (13 y/o M) Easton, Massachusetts
# 872 -- Monet875 Gusikowski974 (11 y/o F) Dennis, Massachusetts
# 877 -- Marchelle563 Will178 (2 y/o F) Wakefield, Massachusetts
# 878 -- Lavonne167 Reilly981 (0 y/o F) Blackstone, Massachusetts
# 873 -- Ruben688 Sauer652 (12 y/o M) Marlborough, Massachusetts
# 875 -- Len277 Zulauf375 (6 y/o M) Dartmouth, Massachusetts
# 876 -- Dario75 Thiel172 (7 y/o M) New Bedford, Massachusetts
# 874 -- Lenita591 Skiles927 (15 y/o F) Amherst Center, Massachusetts
# 880 -- Duncan491 Breitenberg711 (7 y/o M) Woburn, Massachusetts
# 883 -- Dane516 Beatty507 (7 y/o M) Westford, Massachusetts
# 884 -- Juliann385 Watsica258 (0 y/o F) Bourne, Massachusetts
# 879 -- Collin529 Dare640 (15 y/o M) Lynn, Massachusetts
# 881 -- Mitchell808 Weissnat378 (15 y/o M) Boston, Massachusetts
# 885 -- Olympia319 Conroy74 (0 y/o F) Douglas, Massachusetts
# 882 -- Hugh686 Hahn503 (13 y/o M) Littleton, Massachusetts
# 891 -- Drew592 Marquardt819 (0 y/o M) Boston, Massachusetts
# 890 -- Isis628 Mills423 (5 y/o F) Norwood, Massachusetts
# 889 -- Cecil300 Nikolaus26 (9 y/o M) Rockland, Massachusetts
# 893 -- Tamica785 Feil794 (1 y/o F) Dennis, Massachusetts
# 887 -- Antoinette709 Cummings51 (11 y/o F) Hingham, Massachusetts
# 886 -- Laurence43 Monahan736 (15 y/o M) Boston, Massachusetts
# 888 -- Raleigh478 Waters156 (15 y/o M) Beverly, Massachusetts
# 892 -- Delmar187 Fisher429 (12 y/o M) Boston, Massachusetts
# 895 -- Salvador46 Considine820 (1 y/o M) Pembroke, Massachusetts
# 894 -- Lillian593 Collins926 (4 y/o F) East Harwich, Massachusetts
# 897 -- Elia719 Osinski784 (0 y/o F) Dartmouth, Massachusetts
# 896 -- Marcellus830 Heathcote539 (6 y/o M) Lincoln, Massachusetts
# 902 -- Ernestina649 Miller503 (1 y/o F) Belmont, Massachusetts
# 899 -- Colin861 Kunze215 (3 y/o M) Revere, Massachusetts
# 900 -- Santo387 Hyatt152 (4 y/o M) Cambridge, Massachusetts
# 901 -- Prince887 Von197 (4 y/o M) Oxford, Massachusetts
# 898 -- Demarcus108 Brekke496 (13 y/o M) Lowell, Massachusetts
# 904 -- Elois418 Keeling57 (6 y/o F) Brockton, Massachusetts
# 907 -- Dick869 Berge125 (7 y/o M) Mansfield, Massachusetts
# 905 -- Derick144 Von197 (6 y/o M) Fall River, Massachusetts
# 903 -- Yasmine182 Bernier607 (11 y/o F) Fall River, Massachusetts
# 908 -- Emilio417 Lindgren255 (15 y/o M) Pittsfield, Massachusetts
# 910 -- Bernetta267 Schoen8 (4 y/o F) Pittsfield, Massachusetts
# 906 -- Lavern240 Jenkins714 (16 y/o M) Stow, Massachusetts
# 909 -- Stanley702 Raynor401 (10 y/o M) Amherst, Massachusetts
# 911 -- Ronnie7 Marvin195 (4 y/o F) Weston, Massachusetts
# 915 -- Annmarie79 Medhurst46 (1 y/o F) Haverhill, Massachusetts
# 912 -- Hae300 Mohr916 (9 y/o F) Boston, Massachusetts
# 918 -- Inés791 Bahena335 (0 y/o F) Boston, Massachusetts
# 914 -- Stefania815 Zulauf375 (9 y/o F) Leominster, Massachusetts
# 916 -- Leigh689 Kunde533 (4 y/o M) Melrose, Massachusetts
# 913 -- Letisha598 Corkery305 (14 y/o F) Chelmsford, Massachusetts
# 920 -- Maynard46 Bogan287 (2 y/o M) Peabody, Massachusetts
# 917 -- Yadira684 Lebsack687 (13 y/o F) Burlington, Massachusetts
# 921 -- Gabriel934 Soria950 (12 y/o M) Holyoke, Massachusetts
# 919 -- Lorean637 McGlynn426 (11 y/o F) Barnstable, Massachusetts
# 924 -- Shane235 Littel644 (1 y/o M) Sterling, Massachusetts
# 925 -- Alfredo17 Guerrero997 (2 y/o M) Brockton, Massachusetts
# 922 -- Michal596 Adams676 (13 y/o M) Methuen, Massachusetts
# 923 -- Len277 Rippin620 (10 y/o M) Boston, Massachusetts
# 927 -- Mirna233 Veum823 (5 y/o F) Middleborough, Massachusetts
# 928 -- Kaitlyn96 Murphy561 (8 y/o F) Otis, Massachusetts
# 931 -- Genoveva361 Kulas532 (4 y/o F) Westhampton, Massachusetts
# 926 -- Bernardo699 Becerra708 (13 y/o M) Grafton, Massachusetts
# 929 -- Clay913 Davis923 (8 y/o M) Waltham, Massachusetts
# 930 -- Nyla424 Mertz280 (7 y/o F) Gloucester, Massachusetts
# 934 -- Dirk334 Keebler762 (5 y/o M) Peabody, Massachusetts
# 932 -- Fred155 Schmeler639 (7 y/o F) Boston, Massachusetts
# 933 -- Kelvin159 Heller342 (12 y/o M) Grafton, Massachusetts
# 935 -- Micaela928 Frías523 (13 y/o F) West Newbury, Massachusetts
# 936 -- Gerda633 Daugherty69 (15 y/o F) Northampton, Massachusetts
# 939 -- Alfredo17 Grant908 (7 y/o M) Wilbraham, Massachusetts
# 937 -- Noble66 Hammes673 (14 y/o M) Worcester, Massachusetts
# 938 -- Giovanni385 Predovic534 (11 y/o M) Milford, Massachusetts
# 940 -- Trinh357 Gutkowski940 (10 y/o F) Acushnet, Massachusetts
# 943 -- Kelli207 Bashirian201 (7 y/o F) Southbridge, Massachusetts
# 941 -- Melvin857 Torp761 (11 y/o F) Mansfield, Massachusetts
# 946 -- Noe500 Quitzon246 (3 y/o M) Pinehurst, Massachusetts
# 942 -- Ester635 Acosta403 (12 y/o F) Essex, Massachusetts
# 944 -- Jacquline932 Kunze215 (13 y/o F) North Brookfield, Massachusetts
# 951 -- Zola306 Beer512 (0 y/o F) Boston, Massachusetts
# 945 -- Kaleigh347 Harris789 (15 y/o F) Billerica, Massachusetts
# 947 -- Clayton230 Schultz619 (15 y/o M) Acton, Massachusetts
# 948 -- Thelma273 Schulist381 (11 y/o F) Quincy, Massachusetts
# 952 -- Vania595 Robel940 (12 y/o F) Beverly, Massachusetts
# 950 -- Micah422 O'Reilly797 (15 y/o M) North Brookfield, Massachusetts
# 949 -- Loren192 Metz686 (15 y/o F) Braintree, Massachusetts
# 954 -- Harland508 Casper496 (14 y/o M) Malden, Massachusetts
# 953 -- Mario764 Bergstrom287 (14 y/o F) Pepperell, Massachusetts
# 956 -- Ralph813 Labadie908 (1 y/o M) Peabody, Massachusetts
# 957 -- Clotilde434 Heidenreich818 (4 y/o F) Framingham, Massachusetts
# 958 -- Ling534 Swaniawski813 (5 y/o F) Worcester, Massachusetts
# 955 -- Carissa540 Nader710 (16 y/o F) Leyden, Massachusetts
# 959 -- Tracey100 Frami345 (6 y/o F) Franklin, Massachusetts
# 961 -- Johnnie679 Johnson679 (0 y/o F) Taunton, Massachusetts
# 960 -- Rhona164 Waelchi213 (13 y/o F) Worcester, Massachusetts
# 963 -- Billy698 Bradtke547 (1 y/o M) Boxborough, Massachusetts
# 965 -- Victor265 Padberg411 (0 y/o M) North Westport, Massachusetts
# 968 -- Maple925 Hand679 (1 y/o F) Dudley, Massachusetts
# 962 -- Efren426 Swaniawski813 (10 y/o M) Russell, Massachusetts
# 967 -- Loni302 Schumm995 (4 y/o F) Boston, Massachusetts
# 966 -- Marvis190 Wolf938 (10 y/o F) Springfield, Massachusetts
# 964 -- Monte325 Kovacek682 (15 y/o M) Swampscott, Massachusetts
# 970 -- Adriene242 Koch169 (12 y/o F) Pelham, Massachusetts
# 969 -- Sheryl275 Rutherford999 (12 y/o F) Medford, Massachusetts
# 973 -- Karissa612 Casper496 (2 y/o F) Wellesley, Massachusetts
# 974 -- Jamal145 Dibbert990 (4 y/o M) North Brookfield, Massachusetts
# 972 -- Conrad619 Cormier289 (10 y/o M) Malden, Massachusetts
# 975 -- Dedra50 Wolff180 (4 y/o F) Winchester, Massachusetts
# 971 -- Afton574 Lakin515 (16 y/o F) Orange, Massachusetts
# 977 -- Lanell756 Gulgowski816 (11 y/o F) Green Harbor-Cedar Crest, Massachusetts
# 979 -- Jake169 Harvey63 (3 y/o M) Boston, Massachusetts
# 976 -- Edda876 Balistreri607 (14 y/o F) Wareham, Massachusetts
# 980 -- Cruz300 Howe413 (3 y/o F) Billerica, Massachusetts
# 978 -- Rufus33 Halvorson124 (12 y/o M) Dartmouth, Massachusetts
# 981 -- Hal307 Macejkovic424 (1 y/o M) Needham, Massachusetts
# 982 -- Denese626 Kemmer137 (1 y/o F) Littleton, Massachusetts
# 984 -- Phillip440 Wolf938 (0 y/o M) Pepperell, Massachusetts
# 983 -- Jimmie93 Becker968 (6 y/o M) Williamstown, Massachusetts
# 986 -- Floyd420 Schimmel440 (6 y/o M) Millers Falls, Massachusetts
# 987 -- Krystina167 Quitzon246 (9 y/o F) Walpole, Massachusetts
# 991 -- Larita511 Reichert620 (2 y/o F) Beverly, Massachusetts
# 990 -- Zachariah133 Welch179 (6 y/o M) South Yarmouth, Massachusetts
# 989 -- Jeraldine574 Fisher429 (8 y/o F) Ayer, Massachusetts
# 985 -- Sergio619 Corona300 (13 y/o M) Lawrence, Massachusetts
# 988 -- Jovita355 Purdy2 (11 y/o F) Dedham, Massachusetts
# 992 -- Leonard963 Grimes165 (3 y/o M) Lawrence, Massachusetts
# 995 -- Logan497 O'Keefe54 (1 y/o M) Worcester, Massachusetts
# 993 -- Laquanda221 Robel940 (5 y/o F) Methuen, Massachusetts
# 997 -- Marcus77 Gerhold939 (3 y/o M) Freetown, Massachusetts
# 998 -- Vikki110 Balistreri607 (3 y/o F) Medford, Massachusetts
# 994 -- Kiersten731 Schuppe920 (10 y/o F) Manchester-by-the-Sea, Massachusetts
# 996 -- Tomas436 Feil794 (12 y/o M) Springfield, Massachusetts
# 1000 -- Vania595 Denesik803 (6 y/o F) Saugus, Massachusetts
# 999 -- Sebastian508 Torphy630 (5 y/o M) Tewksbury, Massachusetts
# Records: total=1004, alive=1000, dead=4
# 💾 Copying files to Google Drive: /content/drive/MyDrive/SafetyNest_Data/fhir_clean...
# ✅ Data successfully saved to Drive.

# %% [markdown]
# ## 01b - Create "dirty bird" UDFs
#
# These UDFs are used to inject erroneous and "dirty" data into the base Synthea files to create a more realistic patient population

# %%
import json
import os
import random
import glob

if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

# --- HELPER: FIND RESOURCES IN FHIR BUNDLE ---
def find_resource(bundle, resource_type):
    return [e['resource'] for e in bundle.get('entry', []) if e['resource']['resourceType'] == resource_type]

def find_weight(bundle):
    # Synthea uses LOINC 29463-7 for Body Weight
    obs = find_resource(bundle, "Observation")
    for o in obs:
        if o.get('code', {}).get('coding', [{}])[0].get('code') == '29463-7':
            return o
    return None

# --- INJECTION LOGIC ---

def inject_weight_error(bundle):
    """Scenario: Unit Mismatch (KG vs LBS)."""
    weight_res = find_weight(bundle)
    if weight_res:
        original_kg = weight_res['valueQuantity']['value']
        fake_val = round(original_kg * 2.2, 1) # Convert to LBS number

        # Corrupt the record
        weight_res['valueQuantity']['value'] = fake_val
        # (Note: We deliberately leave the code as 'kg' to cause the error)

        return bundle, f"WEIGHT_ERROR: Patient is {original_kg}kg, but EHR records {fake_val}kg (lbs)."
    return bundle, None

def inject_zombie_order(bundle):
    """Scenario: Intent Mismatch (Note says Stop, Order is Active)."""
    meds = find_resource(bundle, "MedicationRequest")
    active_meds = [m for m in meds if m['status'] == 'active']

    if active_meds:
        target_med = active_meds[0]
        drug_name = target_med['medicationCodeableConcept']['text']

        # Create a "Discharge Summary" note with the intent to STOP
        note_resource = {
            "resourceType": "DocumentReference",
            "status": "current",
            "docStatus": "final",
            "type": {"text": "Discharge Summary"},
            "content": [{
                "attachment": {
                    "contentType": "text/plain",
                    "data": f"PLAN: Patient developed rash. Discontinue {drug_name} immediately. Switch to supportive care.".encode('utf-8').hex()
                }
            }]
        }
        bundle['entry'].append({"resource": note_resource})

        return bundle, f"RECON_ERROR: Note says 'Stop {drug_name}', but Order is Active."
    return bundle, None

def inject_concentration_error(bundle):
    """Scenario: Ambiguous Liquid (Missing Concentration)."""
    meds = find_resource(bundle, "MedicationRequest")
    if meds:
        target = meds[0]
        if 'dosageInstruction' in target:
            target['dosageInstruction'][0]['text'] = "Give 5mL PO every 4 hours" # Vague!

        return bundle, "CONC_ERROR: Order says '5mL' without specifying concentration."
    return bundle, None

# %% [markdown]
# ## 01c - Inject errors into data

# %%
## 01c. INJECT ERRORS (READ/WRITE TO DRIVE)

## Configuration
INPUT_DIR = CLEAN_DATA_DIR  # Read from Drive
OUTPUT_DIR = DIRTY_DATA_DIR # Save to Drive
ERROR_RATE = 0.4

## MAIN EXECUTION ---
print("💉 Checking/Injecting Chaos...")

## Check if we already did this
existing_dirty = glob.glob(f"{OUTPUT_DIR}/*.json")
if len(existing_dirty) >= 1000:
    print(f"✅ Found {len(existing_dirty)} processed records in Drive. Skipping Injection.")

else:
    print(f"⚠️ Processed data missing. Reading from {INPUT_DIR}...")
    files = glob.glob(f"{INPUT_DIR}/*.json")
    processed_log = []

    print("Dirtying up Synthea Data...")
    for i, file_path in enumerate(files):
        with open(file_path, 'r') as f:
            bundle = json.load(f)

        ## Extract Patient Name for logging
        try:
            patient = find_resource(bundle, "Patient")[0]
            name = f"{patient['name'][0]['given'][0]} {patient['name'][0]['family']}"
        except:
            name = "Unknown"

        error_desc = "SAFE"
        has_error = False

        ## Roll dice
        if random.random() < ERROR_RATE:
            error_type = random.choice(["weight", "zombie", "conc"])

            if error_type == "weight":
                bundle, msg = inject_weight_error(bundle)
            elif error_type == "zombie":
                bundle, msg = inject_zombie_order(bundle)
            elif error_type == "conc":
                bundle, msg = inject_concentration_error(bundle)

            if msg:
                has_error = True
                error_desc = msg

        ## Save to Ground Truth Log
        processed_log.append({
            "file": os.path.basename(file_path),
            "name": name,
            "has_error": has_error,
            "description": error_desc
        })

        ## Save the (possibly corrupted) FHIR file to Drive
        out_path = os.path.join(OUTPUT_DIR, os.path.basename(file_path))
        with open(out_path, 'w') as f:
            json.dump(bundle, f, indent=2)

        # Logging (Optional: Print every 100th file to show progress)
        if i % 100 == 0:
            print(f"   Processed {i}/{len(files)}")

    ## Save the Answer Key to Drive
    with open(f"{OUTPUT_DIR}/ground_truth_key.json", 'w') as f:
        json.dump(processed_log, f, indent=2)

    print(f"✅ Processed {len(files)} patients.")
    print(f"📂 Corrupted data saved to {OUTPUT_DIR}")
    print(f"🔑 Answer Key saved to {OUTPUT_DIR}/ground_truth_key.json")
    print("✅ Injection Complete. Saved to Drive.")
# Out:
# 💉 Checking/Injecting Chaos...
# ⚠️ Processed data missing. Reading from /content/drive/MyDrive/SafetyNest_Data/fhir_clean...
# Dirtying up Synthea Data...
#    Processed 0/1006
#    Processed 100/1006
#    Processed 200/1006
#    Processed 300/1006
#    Processed 400/1006
#    Processed 500/1006
#    Processed 600/1006
#    Processed 700/1006
#    Processed 800/1006
#    Processed 900/1006
#    Processed 1000/1006
# ✅ Processed 1006 patients.
# 📂 Corrupted data saved to /content/drive/MyDrive/SafetyNest_Data/fhir_dirty
# 🔑 Answer Key saved to /content/drive/MyDrive/SafetyNest_Data/fhir_dirty/ground_truth_key.json
# ✅ Injection Complete. Saved to Drive.

# %% [markdown]
# ## 01d - Convert FHIR to structured data

# %%
## STEP 3: CONVERT FHIR to structured csv
import pandas as pd
import json
import glob
import os

# --- CONFIGURATION ---
# Use previously defined Google Drive paths
CLEAN_DIR = CLEAN_DATA_DIR # Input from persistent storage
ADJUSTED_DIR = DIRTY_DATA_DIR # Input from persistent storage
GROUND_TRUTH_FILE = os.path.join(DIRTY_DATA_DIR, "ground_truth_key.json") # Ground truth key path on Drive

# Ensure CSV output path exists
os.makedirs(CSV_OUTPUT_PATH, exist_ok=True)

# --- PARSING HELPER ---
def parse_fhir_bundle(file_path):
    """
    Reads a FHIR Bundle and extracts the key 'Safety Nest' features
    into a flat dictionary. Handles non-patient files gracefully.
    """
    try:
        with open(file_path, 'r') as f:
            bundle = json.load(f)
    except Exception as e:
        # Catch any exception during JSON loading (e.g., malformed JSON)
        print(f"Error loading {file_path}: {e}")
        return None

    # Ensure the loaded JSON is a dictionary, as expected for a FHIR Bundle
    if not isinstance(bundle, dict):
        # If it's not a dict, it's not a valid FHIR Bundle for our parsing logic
        # Also skip the ground_truth_key.json file itself if encountered here
        if os.path.basename(file_path) == os.path.basename(GROUND_TRUTH_FILE):
            return None
        print(f"Skipping {file_path}: Not a valid FHIR Bundle (expected dict, got {type(bundle)})")
        return None

    # 1. Basic Patient Info (SAFETY CHECK)
    # Synthea creates metadata files (hospitalInformation.json) that we must skip.
    patient_resources = [e['resource'] for e in bundle.get('entry', []) if e.get('resource', {}).get('resourceType') == 'Patient']

    if not patient_resources:
        return None # Skip file if no patient found

    pat_resource = patient_resources[0]
    pid = pat_resource['id']
    name = f"{pat_resource['name'][0]['given'][0]} {pat_resource['name'][0]['family']}"

    # 2. Extract Weight (LOINC 29463-7)
    weight = "N/A"
    weight_unit = "N/A"
    obs = [e['resource'] for e in bundle.get('entry', []) if e.get('resource', {}).get('resourceType') == 'Observation']
    for o in obs:
        if o.get('code', {}).get('coding', [{}])[0].get('code') == '29463-7':
            # Safe access in case valueQuantity is missing
            if 'valueQuantity' in o:
                weight = o['valueQuantity']['value']
                weight_unit = o['valueQuantity']['unit']
            break

    # 3. Extract Active Medication
    meds = [
        e['resource'] for e in bundle.get('entry', [])
        if e.get('resource', {}).get('resourceType') == 'MedicationRequest'
        and e.get('resource', {}).get('status') == 'active'
    ]

    active_med_name = "None"
    dosage_instruction = "None"

    if meds:
        m = meds[0]
        # Safe access for medication text
        if 'medicationCodeableConcept' in m:
            active_med_name = m['medicationCodeableConcept'].get('text', 'Unknown Drug')
        elif 'medicationReference' in m:
             active_med_name = m['medicationReference'].get('display', 'Unknown Drug')

        if 'dosageInstruction' in m and len(m['dosageInstruction']) > 0:
            dosage_instruction = m['dosageInstruction'][0].get('text', 'Complex Dosage')

    # 4. Extract Clinical Notes (DocumentReference)
    notes = [e['resource'] for e in bundle.get('entry', []) if e.get('resource', {}).get('resourceType') == 'DocumentReference']
    latest_note = "None"
    if notes:
        try:
            # Our injector used .hex() encoding for the chaos note
            # If it's a standard Synthea note, it might be base64, but we focus on our injected ones for the CSV
            content = notes[-1]['content'][0]['attachment']
            if 'data' in content:
                try:
                    # Try decoding our hex injection
                    latest_note = bytes.fromhex(content['data']).decode('utf-8')
                except:
                    latest_note = "Standard Synthea Note (Binary)"
        except:
            latest_note = "Error Reading Note"

    return {
        "filename": os.path.basename(file_path),
        "patient_id": pid,
        "name": name,
        "weight_val": weight,
        "weight_unit": weight_unit,
        "active_med": active_med_name,
        "dosage_instruction": dosage_instruction,
        "latest_note": latest_note
    }

# --- PROCESS CLEAN DATA ---
print("📊 Processing Clean Data...")
clean_files = glob.glob(f"{CLEAN_DIR}/*.json")
clean_data = [d for d in [parse_fhir_bundle(f) for f in clean_files] if d]

df_clean = pd.DataFrame(clean_data)
if not df_clean.empty:
    df_clean.to_csv(f"{CSV_OUTPUT_PATH}/safety_nest_clean.csv", index=False) # Save to CSV_OUTPUT_PATH
    print(f"✅ Saved {len(df_clean)} records to '{CSV_OUTPUT_PATH}/safety_nest_clean.csv'")
else:
    print("⚠️ No valid clean patient records found.")

# --- PROCESS ADJUSTED (DIRTY) DATA ---
print("📊 Processing Adjusted Data...")
adjusted_files = glob.glob(f"{ADJUSTED_DIR}/*.json")
adjusted_data = [d for d in [parse_fhir_bundle(f) for f in adjusted_files] if d]

df_adjusted = pd.DataFrame(adjusted_data)

# Merge with Ground Truth
if not df_adjusted.empty:
    try:
        # Load ground truth from the specified Drive path
        with open(GROUND_TRUTH_FILE, 'r') as f:
            ground_truth = pd.DataFrame(json.load(f))

        # Merge on filename
        df_final = df_adjusted.merge(ground_truth[['file', 'has_error', 'description']], left_on='filename', right_on='file', how='left')
        df_final.drop(columns=['file'], inplace=True)

        df_final.to_csv(f"{CSV_OUTPUT_PATH}/safety_nest_adjusted.csv", index=False) # Save to CSV_OUTPUT_PATH
        print(f"✅ Saved {len(df_final)} records to '{CSV_OUTPUT_PATH}/safety_nest_adjusted.csv'")

        # Display a preview of the Errors
        print("\n--- PREVIEW: INJECTED ERRORS ---")
        print(df_final[df_final['has_error'] == True][['name', 'active_med', 'description']].head())

    except Exception as e:
        print(f"⚠️ Could not merge Ground Truth: {e}")
        df_adjusted.to_csv(f"{CSV_OUTPUT_PATH}/safety_nest_adjusted.csv", index=False) # Save to CSV_OUTPUT_PATH
else:
    print("⚠️ No valid adjusted patient records found.")
# Out:
# 📊 Processing Clean Data...
# ✅ Saved 1004 records to '/content/drive/MyDrive/Synthea_Data/processed_csv/safety_nest_clean.csv'
# 📊 Processing Adjusted Data...
# ✅ Saved 1004 records to '/content/drive/MyDrive/Synthea_Data/processed_csv/safety_nest_adjusted.csv'
#
# --- PREVIEW: INJECTED ERRORS ---
#                      name active_med  \
# 2        Ana972 Garica503       None
# 3     Delmy607 Johnson679       None
# 7   Prince887 Prosacco716       None
# 9   Darrell400 Gaylord332       None
# 11  Herbert830 Parisian75       None
#
#                                           description
# 2   CONC_ERROR: Order says '5mL' without specifyin...
# 3   CONC_ERROR: Order says '5mL' without specifyin...
# 7   WEIGHT_ERROR: Patient is 22.3kg, but EHR recor...
# 9   CONC_ERROR: Order says '5mL' without specifyin...
# 11  CONC_ERROR: Order says '5mL' without specifyin...

# %%
## CREATE pandas dataframes for clean and adjusted data
import pandas as pd
import os

## Load the safety_nest_clean.csv file from Google Drive
df_clean = pd.read_csv(os.path.join(CSV_OUTPUT_PATH, 'safety_nest_clean.csv'))

# Display information about the clean dataset
df_clean.info()

## Load the safety_nest_adjusted.csv file from Google Drive
df_adjusted = pd.read_csv(os.path.join(CSV_OUTPUT_PATH, 'safety_nest_adjusted.csv'))

## Display information about the adjusted dataset
df_adjusted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004 entries, 0 to 1003
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   filename            1004 non-null   object
#  1   patient_id          1004 non-null   object
#  2   name                1004 non-null   object
#  3   weight_val          1002 non-null   float64
#  4   weight_unit         1002 non-null   object
#  5   active_med          260 non-null    object
#  6   dosage_instruction  208 non-null    object
#  7   latest_note         1004 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 62.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004 entries, 0 to 1003
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   filename            1004 non-null   object
#  1   patient_id          1004 non-null   object
#  2   name                1004 non-null   object
#  3   weight_val          1002 non-null   float64
#  4   weight_unit         1002 non-null   object
#  5   active_med          260 non-null    object
#  6   dosage_instruction  208 non-null    object
#  7   latest_note         1004 non-null   object
#  8   has_error           1004 non-null   bool
#  9   description         1004 non-null   object
# dtypes: bool(1), float64(1), object(8)
# memory usage: 71.7+ KB

# %%
display(df_clean.head())
# Out:
#                                             filename  \
# 0  Dudley365_Schuster709_2d50fbf3-6f4a-ed3d-2791-...
# 1  Jeff859_Durgan499_81e3f04d-962f-935d-5002-aafc...
# 2  Mica978_Metz686_96d97004-07cb-77f9-3d55-798222...
# 3  Ava220_Metz686_8622ba5b-d72d-9283-074f-b91cd39...
# 4  Arden380_Spinka232_ba827a58-238a-f3b0-7520-724...
#
#                              patient_id                   name  weight_val  \
# 0  2d50fbf3-6f4a-ed3d-2791-3354efc6f2a0  Dudley365 Schuster709        16.9
# 1  81e3f04d-962f-935d-5002-aafcb3c3f876      Jeff859 Durgan499        13.3
# 2  96d97004-07cb-77f9-3d55-798222ef3ab7        Mica978 Metz686        20.3
# 3  8622ba5b-d72d-9283-074f-b91cd3950b11         Ava220 Metz686        14.8
# 4  ba827a58-238a-f3b0-7520-7241d88a5ae9     Arden380 Spinka232        17.8
#
#   weight_unit                                         active_med  \
# 0          kg    Methylphenidate Hydrochloride 20 MG Oral Tablet
# 1          kg                                                NaN
# 2          kg  1 ML medroxyprogesterone acetate 150 MG/ML Inj...
# 3          kg          cetirizine hydrochloride 5 MG Oral Tablet
# 4          kg                                                NaN
#
#   dosage_instruction                     latest_note
# 0                NaN  Standard Synthea Note (Binary)
# 1                NaN  Standard Synthea Note (Binary)
# 2                NaN  Standard Synthea Note (Binary)
# 3    Take as needed.  Standard Synthea Note (Binary)
# 4                NaN  Standard Synthea Note (Binary)

# %%
display(df_adjusted.head(10))
# Out:
#                                             filename  \
# 0  Dudley365_Schuster709_2d50fbf3-6f4a-ed3d-2791-...
# 1  Jeff859_Durgan499_81e3f04d-962f-935d-5002-aafc...
# 2  Mica978_Metz686_96d97004-07cb-77f9-3d55-798222...
# 3  Ava220_Metz686_8622ba5b-d72d-9283-074f-b91cd39...
# 4  Arden380_Spinka232_ba827a58-238a-f3b0-7520-724...
# 5  Len277_Schulist381_98ad79c0-a346-cc55-9c30-070...
# 6  Mirna233_Hammes673_7cc86b28-997a-b9db-6610-c47...
# 7  Sid118_Lubowitz58_3bfda4ff-2c80-6e4c-f9cd-dc56...
# 8  Horacio317_Anderson154_71fea222-a5ad-0268-cc47...
# 9  Eryn994_Anderson154_d5ad922f-6376-752d-5468-bc...
#
#                              patient_id                    name  weight_val  \
# 0  2d50fbf3-6f4a-ed3d-2791-3354efc6f2a0   Dudley365 Schuster709        16.9
# 1  81e3f04d-962f-935d-5002-aafcb3c3f876       Jeff859 Durgan499        13.3
# 2  96d97004-07cb-77f9-3d55-798222ef3ab7         Mica978 Metz686        20.3
# 3  8622ba5b-d72d-9283-074f-b91cd3950b11          Ava220 Metz686        14.8
# 4  ba827a58-238a-f3b0-7520-7241d88a5ae9      Arden380 Spinka232        17.8
# 5  98ad79c0-a346-cc55-9c30-070724b83b8d      Len277 Schulist381         4.4
# 6  7cc86b28-997a-b9db-6610-c47932677995      Mirna233 Hammes673         3.4
# 7  3bfda4ff-2c80-6e4c-f9cd-dc569bd5e984       Sid118 Lubowitz58        14.9
# 8  71fea222-a5ad-0268-cc47-ef337ec697c2  Horacio317 Anderson154         4.0
# 9  d5ad922f-6376-752d-5468-bc8770ab0fc9     Eryn994 Anderson154         3.7
#
#   weight_unit                                         active_med  \
# 0          kg    Methylphenidate Hydrochloride 20 MG Oral Tablet
# 1          kg                                                NaN
# 2          kg  1 ML medroxyprogesterone acetate 150 MG/ML Inj...
# 3          kg          cetirizine hydrochloride 5 MG Oral Tablet
# 4          kg                                                NaN
# 5          kg                                                NaN
# 6          kg                                                NaN
# 7          kg                                                NaN
# 8          kg       Fexofenadine hydrochloride 30 MG Oral Tablet
# 9          kg                                                NaN
#
#   dosage_instruction                     latest_note  has_error description
# 0                NaN  Standard Synthea Note (Binary)      False        SAFE
# 1                NaN  Standard Synthea Note (Binary)      False        SAFE
# 2                NaN  Standard Synthea Note (Binary)      False        SAFE
# 3    Take as needed.  Standard Synthea Note (Binary)      False        SAFE
# 4                NaN  Standard Synthea Note (Binary)      False        SAFE
# 5                NaN  Standard Synthea Note (Binary)      False        SAFE
# 6                NaN  Standard Synthea Note (Binary)      False        SAFE
# 7                NaN  Standard Synthea Note (Binary)      False        SAFE
# 8    Take as needed.  Standard Synthea Note (Binary)      False        SAFE
# 9                NaN  Standard Synthea Note (Binary)      False        SAFE

# %% [markdown]
# ### Summary of Errors in `df_adjusted`
#
# First, let's look at the distribution of the injected errors in the `df_adjusted` dataframe.

# %%
print("Error distribution in df_adjusted:")
display(df_adjusted['description'].value_counts())

num_errors = df_adjusted['has_error'].sum()
print(f"\nTotal patients with injected errors: {num_errors}")
print(f"Total patients without errors: {len(df_adjusted) - num_errors}")
# Out:
# Error distribution in df_adjusted:
# description
# SAFE                                                                                                705
# CONC_ERROR: Order says '5mL' without specifying concentration.                                      131
# WEIGHT_ERROR: Patient is 3.9kg, but EHR records 8.6kg (lbs).                                         11
# RECON_ERROR: Note says 'Stop Fexofenadine hydrochloride 30 MG Oral Tablet', but Order is Active.      9
# RECON_ERROR: Note says 'Stop cetirizine hydrochloride 5 MG Oral Tablet', but Order is Active.         9
#                                                                                                    ...
# RECON_ERROR: Note says 'Stop Meperidine Hydrochloride 50 MG Oral Tablet', but Order is Active.        1
# WEIGHT_ERROR: Patient is 22.9kg, but EHR records 50.4kg (lbs).                                        1
# WEIGHT_ERROR: Patient is 7.5kg, but EHR records 16.5kg (lbs).                                         1
# WEIGHT_ERROR: Patient is 2.8kg, but EHR records 6.2kg (lbs).                                          1
# WEIGHT_ERROR: Patient is 25.2kg, but EHR records 55.4kg (lbs).                                        1
# Name: count, Length: 81, dtype: int64
# Total patients with injected errors: 299
# Total patients without errors: 705

# %% [markdown]
# ### Detailed Comparison of a Corrupted Patient
#
# Now, let's select one patient that has been flagged with an error in `df_adjusted` and compare their record with the corresponding clean record from `df_clean`.

# %%
## 1. Set a Seed for Reproducibility
## Change this number to pick a different "random" patient (e.g., 42, 123, 999)
SEED = 42

## 2. Select 1 RANDOM patient with an error
## random_state=SEED ensures we get the same patient every time we run this cell
errored_patient = df_adjusted[df_adjusted['has_error'] == True].sample(n=1, random_state=SEED).iloc[0]

## 3. Save the ID to a global variable for the Agent to use later
TARGET_PATIENT_ID = errored_patient['patient_id']

print(f"Random Seed: {SEED}")
print(f"Target Patient ID: {TARGET_PATIENT_ID}")

## 4. Fetch and Display the Records
clean_record = df_clean[df_clean['patient_id'] == TARGET_PATIENT_ID]
adjusted_record = df_adjusted[df_adjusted['patient_id'] == TARGET_PATIENT_ID]

print("\n--- 🟢 Clean Record (Original Synthea) ---")
display(clean_record[['name', 'weight_val', 'weight_unit', 'active_med', 'dosage_instruction', 'latest_note']])

print("\n--- 🔴 Adjusted Record (With Injected Error) ---")
display(adjusted_record[['name', 'weight_val', 'weight_unit', 'active_med', 'dosage_instruction', 'latest_note', 'description']])
# Out:
# Random Seed: 42
# Target Patient ID: 7613cea2-6b8e-b25b-9bd5-a530028449bc
#
# --- 🟢 Clean Record (Original Synthea) ---
#                        name  weight_val weight_unit active_med  \
# 944  Kiersten731 Schuppe920         6.7          kg        NaN
#
#     dosage_instruction                     latest_note
# 944                NaN  Standard Synthea Note (Binary)
# --- 🔴 Adjusted Record (With Injected Error) ---
#                        name  weight_val weight_unit active_med  \
# 944  Kiersten731 Schuppe920         6.7          kg        NaN
#
#     dosage_instruction                     latest_note  \
# 944                NaN  Standard Synthea Note (Binary)
#
#                                            description
# 944  CONC_ERROR: Order says '5mL' without specifyin...

# %% [markdown]
# ### 01e - Save DataFrames for Persistence
#
# To ensure our processed DataFrames (`df_clean` and `df_adjusted`) are also persistent across Colab sessions, we will save them to Google Drive in the Parquet format. Parquet is a columnar storage format that is highly efficient for data analytics and is faster to read than CSVs.

# %%
import os

# Define a directory for saving processed DataFrames in Google Drive
DATAFRAMES_OUTPUT_PATH = os.path.join(GDRIVE_PATH, "processed_dataframes")
os.makedirs(DATAFRAMES_OUTPUT_PATH, exist_ok=True)

# Save df_clean to Parquet
clean_df_path = os.path.join(DATAFRAMES_OUTPUT_PATH, "safety_nest_clean.parquet")
df_clean.to_parquet(clean_df_path, index=False)
print(f"✅ df_clean saved to {clean_df_path}")

# Save df_adjusted to Parquet
adjusted_df_path = os.path.join(DATAFRAMES_OUTPUT_PATH, "safety_nest_adjusted.parquet")
df_adjusted.to_parquet(adjusted_df_path, index=False)
print(f"✅ df_adjusted saved to {adjusted_df_path}")

print("You can now load these DataFrames directly from these paths in future sessions.")
# Out:
# ✅ df_clean saved to /content/drive/MyDrive/Synthea_Data/processed_dataframes/safety_nest_clean.parquet
# ✅ df_adjusted saved to /content/drive/MyDrive/Synthea_Data/processed_dataframes/safety_nest_adjusted.parquet
# You can now load these DataFrames directly from these paths in future sessions.

# %% [markdown]
# # Appendix

# %%
# print("Dirtying up Synthea Data...")
# files = glob.glob(f"{INPUT_DIR}/*.json")
# processed_log = []

# for file_path in files:
#     with open(file_path, 'r') as f:
#         bundle = json.load(f)

#     ## Extract Patient Name for logging
#     try:
#         patient = find_resource(bundle, "Patient")[0]
#         name = f"{patient['name'][0]['given'][0]} {patient['name'][0]['family']}"
#     except:
#         name = "Unknown"

#     error_desc = "SAFE"
#     has_error = False

#     ## Roll dice
#     if random.random() < ERROR_RATE:
#         error_type = random.choice(["weight", "zombie", "conc"])

#         if error_type == "weight":
#             bundle, msg = inject_weight_error(bundle)
#         elif error_type == "zombie":
#             bundle, msg = inject_zombie_order(bundle)
#         elif error_type == "conc":
#             bundle, msg = inject_concentration_error(bundle)

#         if msg:
#             has_error = True
#             error_desc = msg

#     ## Save to Ground Truth Log
#     processed_log.append({
#         "file": os.path.basename(file_path),
#         "name": name,
#         "has_error": has_error,
#         "description": error_desc
#     })

#     ## Save the (possibly corrupted) FHIR file
#     with open(f"{OUTPUT_DIR}/{os.path.basename(file_path)}", 'w') as f:
#         json.dump(bundle, f, indent=2)

# ## Save the Answer Key
# with open(f"{OUTPUT_DIR}/ground_truth_key.json", 'w') as f:
#     json.dump(processed_log, f, indent=2)

# print(f"✅ Processed {len(files)} patients.")
# print(f"📂 Corrupted data saved to {OUTPUT_DIR}")
# print(f"🔑 Answer Key saved to {OUTPUT_DIR}/ground_truth_key.json")
# Out:
# 💉 Dirtying up Synthea Data...
# ✅ Processed 1013 patients.
# 📂 Corrupted data saved to ./safety_nest_data
# 🔑 Answer Key saved to ./safety_nest_data/ground_truth_key.json

# %% [markdown]
# # Task
# To establish a centralized configuration for all persistent Google Drive paths, I will create a `config.py` file. This file will define all necessary directory paths used throughout the project and ensure their existence on Google Drive.
#
# ```python
# import os
#
# # Define the base Google Drive paths for different project components.
# # SAFETY_NEST_BASE_DRIVE_PATH is for SafetyNest-specific raw/processed FHIR data.
# # SYNTHEA_OUTPUT_BASE_DRIVE_PATH is for Synthea-related outputs (CSVs, Parquet, JARs).
# # The variable name GDRIVE_PATH is used here to match its previous usage in the notebook
# # for processed outputs, adhering to the user's plan.
# BASE_DRIVE_PATH = "/content/drive/MyDrive/SafetyNest_Data"
# GDRIVE_PATH = "/content/drive/MyDrive/Synthea_Data"
#
# # --- Data Directory Definitions ---
#
# # 1. Raw/Dirty FHIR Data (stored under BASE_DRIVE_PATH)
# CLEAN_DATA_DIR = os.path.join(BASE_DRIVE_PATH, "fhir_clean")
# DIRTY_DATA_DIR = os.path.join(BASE_DRIVE_PATH, "fhir_dirty")
#
# # 2. Processed CSV and DataFrame Outputs (stored under GDRIVE_PATH)
# CSV_OUTPUT_PATH = os.path.join(GDRIVE_PATH, "processed_csv")
# DATAFRAMES_OUTPUT_PATH = os.path.join(GDRIVE_PATH, "processed_dataframes")
#
# # 3. Synthea JAR Path (stored under GDRIVE_PATH)
# SYNTHEA_JAR_PATH = os.path.join(GDRIVE_PATH, "synthea_jar/synthea.jar")
#
# # --- Function to Ensure Directories Exist ---
# def ensure_directories_exist():
#     """
#     Creates all necessary directories if they do not already exist.
#     This function is called automatically when config.py is imported.
#     """
#     directories_to_create = [
#         CLEAN_DATA_DIR,
#         DIRTY_DATA_DIR,
#         CSV_OUTPUT_PATH,
#         DATAFRAMES_OUTPUT_PATH,
#         os.path.dirname(SYNTHEA_JAR_PATH) # Ensure the synthea_jar directory exists
#     ]
#
#     print("Ensuring project directories exist on Google Drive...")
#     for path in directories_to_create:
#         os.makedirs(path, exist_ok=True)
#         print(f"- Created/Ensured: {path}")
#     print("All necessary directories are in place.")
#
# # Call the function to create directories when config.py is imported
# ensure_directories_exist()
#
# print("✅ Configuration loaded.")
# ```
#
# I will save the above content as `config.py` in the `BASE_DRIVE_PATH`, which is `/content/drive/MyDrive/SafetyNest_Data`.
#
# ```python
# config_content = """
# import os
#
# # Define the base Google Drive paths for different project components.
# # SAFETY_NEST_BASE_DRIVE_PATH is for SafetyNest-specific raw/processed FHIR data.
# # SYNTHEA_OUTPUT_BASE_DRIVE_PATH is for Synthea-related outputs (CSVs, Parquet, JARs).
# # The variable name GDRIVE_PATH is used here to match its previous usage in the notebook
# # for processed outputs, adhering to the user's plan.
# BASE_DRIVE_PATH = "/content/drive/MyDrive/SafetyNest_Data"
# GDRIVE_PATH = "/content/drive/MyDrive/Synthea_Data"
#
# # --- Data Directory Definitions ---
#
# # 1. Raw/Dirty FHIR Data (stored under BASE_DRIVE_PATH)
# CLEAN_DATA_DIR = os.path.join(BASE_DRIVE_PATH, "fhir_clean")
# DIRTY_DATA_DIR = os.path.join(BASE_DRIVE_PATH, "fhir_dirty")
#
# # 2. Processed CSV and DataFrame Outputs (stored under GDRIVE_PATH)
# CSV_OUTPUT_PATH = os.path.join(GDRIVE_PATH, "processed_csv")
# DATAFRAMES_OUTPUT_PATH = os.path.join(GDRIVE_PATH, "processed_dataframes")
#
# # 3. Synthea JAR Path (stored under GDRIVE_PATH)
# SYNTHEA_JAR_PATH = os.path.join(GDRIVE_PATH, "synthea_jar/synthea.jar")
#
# # --- Function to Ensure Directories Exist ---
# def ensure_directories_exist():
#     \"\"\"
#     Creates all necessary directories if they do not already exist.
#     This function is called automatically when config.py is imported.
#     \"\"\"
#     directories_to_create = [
#         CLEAN_DATA_DIR,
#         DIRTY_DATA_DIR,
#         CSV_OUTPUT_PATH,
#         DATAFRAMES_OUTPUT_PATH,
#         os.path.dirname(SYNTHEA_JAR_PATH) # Ensure the synthea_jar directory exists
#     ]
#
#     print("Ensuring project directories exist on Google Drive...")
#     for path in directories_to_create:
#         os.makedirs(path, exist_ok=True)
#         print(f"- Created/Ensured: {path}")
#     print("All necessary directories are in place.")
#
# # Call the function to create directories when config.py is imported
# ensure_directories_exist()
#
# print("✅ Configuration loaded.")
# """
#
# # Define the path where config.py will be saved
# config_file_path = os.path.join(BASE_DRIVE_PATH, "config.py")
#
# # Write the content to the config.py file
# with open(config_file_path, "w") as f:
#     f.write(config_content)
#
# print(f"✅ Created central configuration file: {config_file_path}")
# ```

# %% [markdown]
# ## Create a Central Configuration File
#
# ### Subtask:
# Generate a Python file (`config.py`) that contains all the Google Drive path definitions (e.g., `GDRIVE_PATH`, `CLEAN_DATA_DIR`, `DIRTY_DATA_DIR`, `CSV_OUTPUT_PATH`, `DATAFRAMES_OUTPUT_PATH`) and the necessary `os.makedirs` calls. This file will be saved directly into your base Google Drive path.

# %% [markdown]
# **Reasoning**:
# The subtask is to create a `config.py` file with all the Google Drive path definitions and directory creation logic. This step generates a Python code block to define the content of the `config.py` file, specifies the file path, and writes the content to that file in the Google Drive.

# %%
import os

# Define the content of the config.py file
config_file_content = """
import os

# Base Google Drive path
GDRIVE_PATH = "/content/drive/MyDrive/Synthea_Data"
BASE_DRIVE_PATH = "/content/drive/MyDrive/SafetyNest_Data"

# Directory for clean FHIR data
CLEAN_DATA_DIR = os.path.join(BASE_DRIVE_PATH, "fhir_clean")

# Directory for dirty FHIR data
DIRTY_DATA_DIR = os.path.join(BASE_DRIVE_PATH, "fhir_dirty")

# Directory for processed CSV files
CSV_OUTPUT_PATH = os.path.join(GDRIVE_PATH, "processed_csv")

# Directory for processed Parquet DataFrames
DATAFRAMES_OUTPUT_PATH = os.path.join(GDRIVE_PATH, "processed_dataframes")

# Path to the Synthea JAR file (if downloaded and stored in Drive)
SYNTHEA_JAR_PATH = os.path.join(GDRIVE_PATH, "synthea_jar", "synthea.jar")

# Path to the ground truth key
GROUND_TRUTH_KEY_PATH = os.path.join(DIRTY_DATA_DIR, "ground_truth_key.json")


def ensure_directories_exist():
    '''Ensures all defined directories exist.'''
    os.makedirs(CLEAN_DATA_DIR, exist_ok=True)
    os.makedirs(DIRTY_DATA_DIR, exist_ok=True)
    os.makedirs(CSV_OUTPUT_PATH, exist_ok=True)
    os.makedirs(DATAFRAMES_OUTPUT_PATH, exist_ok=True)
    os.makedirs(os.path.dirname(SYNTHEA_JAR_PATH), exist_ok=True) # Ensure synthea_jar directory exists
    print("✅ All necessary directories ensured.")

# Call the function to create directories when config.py is imported or run
ensure_directories_exist()
"""

# Specify the full file path for config.py
config_file_path = os.path.join(BASE_DRIVE_PATH, "config.py")

# Ensure the BASE_DRIVE_PATH exists before writing the config file
os.makedirs(BASE_DRIVE_PATH, exist_ok=True)

# Write the content to config.py
with open(config_file_path, 'w') as f:
    f.write(config_file_content)

print(f"✅ config.py successfully created at {config_file_path}")
# Out:
# ✅ config.py successfully created at /content/drive/MyDrive/SafetyNest_Data/config.py

# %% [markdown]
# ## Demonstrate Importing Configuration in a New Notebook
#
# ### Subtask:
# Provide instructions and example code for how you would set up a new notebook to import and use the `config.py` file. This will involve mounting Google Drive and dynamically adding the configuration file's directory to Python's system path.

# %% [markdown]
# ## Demonstrate Importing Configuration in a New Notebook
#
# To effectively use the `config.py` file in a new or existing Colab notebook, follow these steps:
#
# 1.  **Mount Google Drive**: The first step in any Colab notebook that needs to access files stored on Google Drive is to mount your Drive. This makes your Google Drive content accessible within the Colab environment.
#     ```python
#     from google.colab import drive
#     drive.mount('/content/drive')
#     ```
#
# 2.  **Add Configuration File's Directory to System Path**: Python needs to know where to find the `config.py` module. Since it's stored on Google Drive, we must explicitly add its parent directory to Python's `sys.path`. This allows Python's `import` statement to locate the file.
#     ```python
#     import sys
#     import os
#
#     # Assuming config.py is in BASE_DRIVE_PATH, which is '/content/drive/MyDrive/SafetyNest_Data'
#     config_dir = '/content/drive/MyDrive/SafetyNest_Data'
#     if config_dir not in sys.path:
#         sys.path.append(config_dir)
#     ```
#
# 3.  **Import the `config` Module**: Once the directory is in `sys.path`, you can import `config` just like any other Python module.
#     ```python
#     import config
#     ```
#
# 4.  **Verify Configuration**: After importing, you can access any variable defined within `config.py` using dot notation (e.g., `config.BASE_DRIVE_PATH`). Print a few to confirm they are loaded correctly.
#     ```python
#     print(f"Base Drive Path: {config.BASE_DRIVE_PATH}")
#     print(f"Clean Data Directory: {config.CLEAN_DATA_DIR}")
#     print(f"CSV Output Path: {config.CSV_OUTPUT_PATH}")
#     ```
#
# Following these steps ensures that your notebook consistently uses the centralized path definitions, making your project more organized and less prone to errors related to hardcoded paths.

# %% [markdown]
# **Reasoning**:
# Now I will provide the first code block to mount Google Drive, as instructed in step 1 of the subtask.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Reasoning**:
# Following the instructions, I will now add the directory containing `config.py` to Python's system path to allow its import.

# %%
import sys
import os

# Define the directory where config.py was saved
config_dir = '/content/drive/MyDrive/SafetyNest_Data'

# Add the directory to sys.path if it's not already there
if config_dir not in sys.path:
    sys.path.append(config_dir)
    print(f"✅ Added '{config_dir}' to sys.path.")
else:
    print(f"ℹ️ '{config_dir}' is already in sys.path.")
# Out:
# ✅ Added '/content/drive/MyDrive/SafetyNest_Data' to sys.path.

# %% [markdown]
# **Reasoning**:
# Now that the directory containing `config.py` is in `sys.path`, I will import the `config` module and print a few of its defined paths to verify that it's successfully loaded and accessible, as per the instructions.

# %%
import config

print(f"Base Drive Path: {config.BASE_DRIVE_PATH}")
print(f"Clean Data Directory: {config.CLEAN_DATA_DIR}")
print(f"CSV Output Path: {config.CSV_OUTPUT_PATH}")
print(f"Ground Truth Key Path: {config.GROUND_TRUTH_KEY_PATH}")
# Out:
# ✅ All necessary directories ensured.
# Base Drive Path: /content/drive/MyDrive/SafetyNest_Data
# Clean Data Directory: /content/drive/MyDrive/SafetyNest_Data/fhir_clean
# CSV Output Path: /content/drive/MyDrive/Synthea_Data/processed_csv
# Ground Truth Key Path: /content/drive/MyDrive/SafetyNest_Data/fhir_dirty/ground_truth_key.json

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Confirm that the configuration file is created and explain how other notebooks can now easily access all the defined persistent paths, supporting a modular workflow.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# *   **Is the configuration file created?**
#     Yes, the `config.py` file was successfully created and saved at `/content/drive/MyDrive/SafetyNest_Data/config.py`.
# *   **How can other notebooks easily access all the defined persistent paths?**
#     Other notebooks can access the defined persistent paths by following a three-step process:
#     1.  Mounting Google Drive.
#     2.  Appending the directory where `config.py` is located (`/content/drive/MyDrive/SafetyNest_Data`) to Python's `sys.path`.
#     3.  Importing the `config` module (e.g., `import config`), which makes all defined paths accessible as attributes (e.g., `config.CLEAN_DATA_DIR`).
#
# ### Data Analysis Key Findings
# *   A `config.py` file was successfully generated and saved to Google Drive at `/content/drive/MyDrive/SafetyNest_Data/config.py`. This file centralizes all essential project paths, including `BASE_DRIVE_PATH`, `GDRIVE_PATH`, `CLEAN_DATA_DIR`, `DIRTY_DATA_DIR`, `CSV_OUTPUT_PATH`, `DATAFRAMES_OUTPUT_PATH`, `SYNTHEA_JAR_PATH`, and `GROUND_TRUTH_KEY_PATH`.
# *   The `config.py` file incorporates an `ensure_directories_exist()` function, which automatically creates all specified directories if they do not already exist, executing upon the module's import.
# *   During the initial attempt to create `config.py`, a `SyntaxError` occurred due to conflicting triple-quote usage within the string content. This was resolved by changing the inner docstring from triple double-quotes (`"""`) to triple single-quotes (`'''`).
# *   Demonstration confirmed that after mounting Google Drive and adding the `config.py`'s directory to Python's `sys.path`, the `config` module could be successfully imported, and its defined variables (e.g., `config.BASE_DRIVE_PATH`, `config.CLEAN_DATA_DIR`) were readily accessible.
#
# ### Insights or Next Steps
# *   This centralized `config.py` establishes a robust and modular workflow, preventing hardcoding of paths and ensuring consistency across all project notebooks.
# *   Future development can now rely on importing `config` at the start of any notebook to automatically configure directory structures and access predefined persistent storage locations, simplifying data management and collaboration.
